# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df1 = pd.read_csv("./Sales_Data/Sales_January_2019.csv")

df2 = pd.read_csv("./Sales_Data/Sales_February_2019.csv")

df3 = pd.read_csv("./Sales_Data/Sales_March_2019.csv")

df4 = pd.read_csv("./Sales_Data/Sales_April_2019.csv")

df5 = pd.read_csv("./Sales_Data/Sales_May_2019.csv")

df6 = pd.read_csv("./Sales_Data/Sales_June_2019.csv")

df7 = pd.read_csv("./Sales_Data/Sales_July_2019.csv")

df8  = pd.read_csv("./sales_Data/Sales_August_2019.csv")

df9 = pd.read_csv("./Sales_Data/Sales_September_2019.csv")

df10 = pd.read_csv("./Sales_Data/Sales_October_2019.csv")

df11 = pd.read_csv("./Sales_Data/Sales_November_2019.csv")

df12 = pd.read_csv("./Sales_Data/Sales_December_2019.csv")


# Merging the Data Frames of the Year of 2019
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12]
df_keys = pd.concat(frames, keys=['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December' ])
df_keys
# Out:
#                Order ID                     Product Quantity Ordered  \
# January  0       141234                      iPhone                1
#          1       141235    Lightning Charging Cable                1
#          2       141236            Wired Headphones                2
#          3       141237            27in FHD Monitor                1
#          4       141238            Wired Headphones                1
# ...                 ...                         ...              ...
# December 25112   319666    Lightning Charging Cable                1
#          25113   319667       AA Batteries (4-pack)                2
#          25114   319668             Vareebadd Phone                1
#          25115   319669            Wired Headphones                1
#          25116   319670  Bose SoundSport Headphones                1
#
#                Price Each      Order Date  \
# January  0            700  01/22/19 21:25
#          1          14.95  01/28/19 14:15
# ...

# %%
df_keys.isnull().sum()
# There are 545 empty values in the dataset
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
# cleaning dataset of null values
newdf = df_keys.dropna()
df_keys = newdf
df_keys

#545 null values removed
# from 186 850 rows to 186 305 rows
# Out:
#                Order ID                     Product Quantity Ordered  \
# January  0       141234                      iPhone                1
#          1       141235    Lightning Charging Cable                1
#          2       141236            Wired Headphones                2
#          3       141237            27in FHD Monitor                1
#          4       141238            Wired Headphones                1
# ...                 ...                         ...              ...
# December 25112   319666    Lightning Charging Cable                1
#          25113   319667       AA Batteries (4-pack)                2
#          25114   319668             Vareebadd Phone                1
#          25115   319669            Wired Headphones                1
#          25116   319670  Bose SoundSport Headphones                1
#
#                Price Each      Order Date  \
# January  0            700  01/22/19 21:25
#          1          14.95  01/28/19 14:15
# ...

# %%
# cleaning each dataset of null values for conversions
ndf1 = df1.dropna()
ndf2 = df2.dropna()
ndf3 = df3.dropna()
ndf4 = df4.dropna()
ndf5 = df5.dropna()
ndf6 = df6.dropna()
ndf7 = df7.dropna()
ndf8 = df8.dropna()
ndf9 = df9.dropna()
ndf10 = df10.dropna()
ndf11 = df11.dropna()
ndf12 = df12.dropna()

ndf1
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
# new monthly rev calculations, month 1
ipmr = ndf1.loc[(ndf1['Product'] == 'iPhone') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
ipmrr1 = pd.to_numeric(ipmr['Quantity Ordered'], errors='coerce')
ipmrr2 = pd.to_numeric(ipmr['Price Each'], errors='coerce')
ippmr1 = (ipmrr1 * ipmrr2).sum().round(2)

lgcabmr = ndf1.loc[(ndf1['Product'] == 'Lightning Charging Cable') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
lgcabmr1 = pd.to_numeric(lgcabmr['Quantity Ordered'], errors='coerce')
lgcabmr2 = pd.to_numeric(lgcabmr['Price Each'], errors='coerce')
lggcabmr1 = (lgcabmr1 * lgcabmr2).sum().round(2)


whmr = ndf1.loc[(ndf1['Product'] == 'Wired Headphones') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
whmr1 = pd.to_numeric(whmr['Quantity Ordered'], errors='coerce')
whmr2 = pd.to_numeric(whmr['Price Each'], errors='coerce')
whphmr1 = (whmr1 * whmr2).sum().round(2)


fhmr = ndf1.loc[(ndf1['Product'] == '27in FHD Monitor') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
fhmr1 = pd.to_numeric(fhmr['Quantity Ordered'], errors='coerce')
fhmr2 = pd.to_numeric(fhmr['Price Each'], errors='coerce')
fhdmonmr1 = (fhmr1 * fhmr2).sum().round(2)


aaamr = ndf1.loc[(ndf1['Product'] == 'AAA Batteries (4-pack)') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
aaabmr1 = pd.to_numeric(aaamr['Quantity Ordered'], errors='coerce')
aaabmr2 = pd.to_numeric(aaamr['Price Each'], errors='coerce')
aaamr1 = (aaabmr1 * aaabmr2).sum().round(2)


gmmr = ndf1.loc[(ndf1['Product'] == '27in 4K Gaming Monitor') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
gmmr1 = pd.to_numeric(gmmr['Quantity Ordered'], errors='coerce')
gmmr2 = pd.to_numeric(gmmr['Price Each'], errors='coerce')
gammonmr1 = (gmmr1 * gmmr2).sum().round(2)


usmr = ndf1.loc[(ndf1['Product'] == 'USB-C Charging Cable') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
usmr1 = pd.to_numeric(usmr['Quantity Ordered'], errors='coerce')
usmr2 = pd.to_numeric(usmr['Price Each'], errors='coerce')
usbcccmr1 = (usmr1 * usmr2).sum().round(2)


bosesmr = ndf1.loc[(ndf1['Product'] == 'Bose SoundSport Headphones') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
bosecmr1 = pd.to_numeric(bosesmr['Quantity Ordered'], errors='coerce')
bosecmr2 = pd.to_numeric(bosesmr['Price Each'], errors='coerce')
bosesmr1 = (bosecmr1 * bosecmr2).sum().round(2)


applemr =  ndf1.loc[(ndf1['Product'] == 'Apple Airpods Headphones') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
applecmr1 = pd.to_numeric(applemr['Quantity Ordered'], errors='coerce')
applecmr2 = pd.to_numeric(applemr['Price Each'], errors='coerce')
applemr1 = (applecmr1 * applecmr2).sum().round(2)


macbmr = ndf1.loc[(ndf1['Product'] == 'Macbook Pro Laptop') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
maccmr1 = pd.to_numeric(macbmr['Quantity Ordered'], errors='coerce')
maccmr2 = pd.to_numeric(macbmr['Price Each'], errors='coerce')
macbmr1 = (maccmr1 * maccmr2).sum().round(2)


flatsmr = ndf1.loc[(ndf1['Product'] == 'Flatscreen TV') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
flatscmr1 = pd.to_numeric(flatsmr['Quantity Ordered'], errors='coerce')
flatscmr2 = pd.to_numeric(flatsmr['Price Each'], errors='coerce')
flatsmr1 = (flatscmr1 * flatscmr2).sum().round(2)


varemr = ndf1.loc[(ndf1['Product'] == 'Vareebadd Phone') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
varecmr1 = pd.to_numeric(varemr['Quantity Ordered'], errors='coerce')
varecmr2 = pd.to_numeric(varemr['Price Each'], errors='coerce')
varemr1 = (varecmr1 * varecmr2).sum().round(2)


aamr = ndf1.loc[(ndf1['Product'] == 'AA Batteries (4-pack)') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
aacmr1 = pd.to_numeric(aamr['Quantity Ordered'], errors='coerce')
aacmr2 = pd.to_numeric(aamr['Price Each'], errors='coerce')
aamr1 = (aacmr1 * aacmr2).sum().round(2)


googmr = ndf1.loc[(ndf1['Product'] == 'Google Phone') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
googcmr1 = pd.to_numeric(googmr['Quantity Ordered'], errors='coerce')
googcmr2 = pd.to_numeric(googmr['Price Each'], errors='coerce')
googmr1 = (googcmr1 * googcmr2).sum().round(2)


monmr = ndf1.loc[(ndf1['Product'] == '20in Monitor') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
moncmr1 = pd.to_numeric(monmr['Quantity Ordered'], errors='coerce')
moncmr2 = pd.to_numeric(monmr['Price Each'], errors='coerce')
monmr1 = (moncmr1 * moncmr2).sum().round(2)


ultramr = ndf1.loc[(ndf1['Product'] == '34in Ultrawide Monitor') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
ultracmr1 = pd.to_numeric(ultramr['Quantity Ordered'], errors='coerce')
ultracmr2 = pd.to_numeric(ultramr['Price Each'], errors='coerce')
ultramr1 = (ultracmr1 * ultracmr2).sum().round(2)


thinkmrl = ndf1.loc[(ndf1['Product'] == 'ThinkPad Laptop') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
thinkcmr1 = pd.to_numeric(thinkmrl['Quantity Ordered'], errors='coerce')
thinkcmr2 = pd.to_numeric(thinkmrl['Price Each'], errors='coerce')
thinklmr1 = (thinkcmr1 * thinkcmr2).sum().round(2)


lgmr = ndf1.loc[(ndf1['Product'] == 'LG Dryer') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
lgmrc1 = pd.to_numeric(lgmr['Quantity Ordered'], errors='coerce')
lgmrc2 = pd.to_numeric(lgmr['Price Each'], errors='coerce')
lgmr1 = (lgmrc1 * lgmrc2).sum().round(2)


lmmr = ndf1.loc[(ndf1['Product'] == 'LG Washing Machine') ^ (ndf1['Quantity Ordered'] == 1) ^ (ndf1['Price Each'] == 1)]
lmmrc1 = pd.to_numeric(lmmr['Quantity Ordered'], errors='coerce')
lmmrc2 = pd.to_numeric(lmmr['Price Each'], errors='coerce')
lmmr1 = (lmmrc1 * lmmrc2).sum().round(2)



# month 1 total:
m1tot = ippmr1 + lggcabmr1 + whphmr1 + fhdmonmr1 + aaamr1 + gammonmr1 + usbcccmr1 + bosesmr1 + applemr1 +macbmr1 + flatsmr1 + varemr1 + aamr1 + googmr1 + monmr1 + ultramr1 + thinklmr1 + lgmr1 + lmmr1
m1tot
# Out:
# 1815335.1200000003

# %%
# new monthly rev calculations, month 2
ipmr2 = ndf2.loc[(ndf2['Product'] == 'iPhone') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] ==1)]
ipmrr21 = pd.to_numeric(ipmr2['Quantity Ordered'], errors='coerce')
ipmrr22 = pd.to_numeric(ipmr2['Price Each'], errors='coerce')
ippmr21 = (ipmrr21 * ipmrr22).sum().round(2)

lgcabmr2 = ndf2.loc[(ndf2['Product'] == 'Lightning Charging Cable') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
lgcabmr21 = pd.to_numeric(lgcabmr2['Quantity Ordered'], errors='coerce')
lgcabmr22 = pd.to_numeric(lgcabmr2['Price Each'], errors='coerce')
lggcabmr21 = (lgcabmr21 * lgcabmr22).sum().round(2)


whmr2 = ndf2.loc[(ndf2['Product'] == 'Wired Headphones') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
whmr21 = pd.to_numeric(whmr2['Quantity Ordered'], errors='coerce')
whmr22 = pd.to_numeric(whmr2['Price Each'], errors='coerce')
whphmr21 = (whmr21 * whmr22).sum().round(2)


fhmr2 = ndf2.loc[(ndf2['Product'] == '27in FHD Monitor') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
fhmr21 = pd.to_numeric(fhmr2['Quantity Ordered'], errors='coerce')
fhmr22 = pd.to_numeric(fhmr2['Price Each'], errors='coerce')
fhdmonmr21 = (fhmr21 * fhmr22).sum().round(2)


aaamr2 = ndf2.loc[(ndf2['Product'] == 'AAA Batteries (4-pack)') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
aaabmr21 = pd.to_numeric(aaamr2['Quantity Ordered'], errors='coerce')
aaabmr22 = pd.to_numeric(aaamr2['Price Each'], errors='coerce')
aaamr21 = (aaabmr21 * aaabmr22).sum().round(2)


gmmr2 = ndf2.loc[(ndf2['Product'] == '27in 4K Gaming Monitor') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
gmmr21 = pd.to_numeric(gmmr2['Quantity Ordered'], errors='coerce')
gmmr22 = pd.to_numeric(gmmr2['Price Each'], errors='coerce')
gammonmr21 = (gmmr21 * gmmr22).sum().round(2)


usmr2 = ndf2.loc[(ndf2['Product'] == 'USB-C Charging Cable') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
usmr21 = pd.to_numeric(usmr2['Quantity Ordered'], errors='coerce')
usmr22 = pd.to_numeric(usmr2['Price Each'], errors='coerce')
usbcccmr21 = (usmr21 * usmr22).sum().round(2)


bosesmr2 = ndf2.loc[(ndf2['Product'] == 'Bose SoundSport Headphones') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
bosecmr21 = pd.to_numeric(bosesmr2['Quantity Ordered'], errors='coerce')
bosecmr22 = pd.to_numeric(bosesmr2['Price Each'], errors='coerce')
bosesmr21 = (bosecmr21 * bosecmr22).sum().round(2)


applemr2 =  ndf2.loc[(ndf2['Product'] == 'Apple Airpods Headphones') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
applecmr21 = pd.to_numeric(applemr2['Quantity Ordered'], errors='coerce')
applecmr22 = pd.to_numeric(applemr2['Price Each'], errors='coerce')
applemr21 = (applecmr21 * applecmr22).sum().round(2)


macbmr2 = ndf2.loc[(ndf2['Product'] == 'Macbook Pro Laptop') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
maccmr21 = pd.to_numeric(macbmr2['Quantity Ordered'], errors='coerce')
maccmr22 = pd.to_numeric(macbmr2['Price Each'], errors='coerce')
macbmr21 = (maccmr21 * maccmr22).sum().round(2)


flatsmr2 = ndf2.loc[(ndf2['Product'] == 'Flatscreen TV') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
flatscmr21 = pd.to_numeric(flatsmr2['Quantity Ordered'], errors='coerce')
flatscmr22 = pd.to_numeric(flatsmr2['Price Each'], errors='coerce')
flatsmr21 = (flatscmr21 * flatscmr22).sum().round(2)


varemr2 = ndf2.loc[(ndf2['Product'] == 'Vareebadd Phone') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
varecmr21 = pd.to_numeric(varemr2['Quantity Ordered'], errors='coerce')
varecmr22 = pd.to_numeric(varemr2['Price Each'], errors='coerce')
varemr21 = (varecmr21 * varecmr22).sum().round(2)


aamr2 = ndf2.loc[(ndf2['Product'] == 'AA Batteries (4-pack)') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
aacmr21 = pd.to_numeric(aamr2['Quantity Ordered'], errors='coerce')
aacmr22 = pd.to_numeric(aamr2['Price Each'], errors='coerce')
aamr21 = (aacmr21 * aacmr22).sum().round(2)


googmr2 = ndf2.loc[(ndf2['Product'] == 'Google Phone') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
googcmr21 = pd.to_numeric(googmr2['Quantity Ordered'], errors='coerce')
googcmr22 = pd.to_numeric(googmr2['Price Each'], errors='coerce')
googmr21 = (googcmr21 * googcmr22).sum().round(2)


monmr2 = ndf2.loc[(ndf2['Product'] == '20in Monitor') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
moncmr21 = pd.to_numeric(monmr2['Quantity Ordered'], errors='coerce')
moncmr22 = pd.to_numeric(monmr2['Price Each'], errors='coerce')
monmr21 = (moncmr21 * moncmr22).sum().round(2)


ultramr2 = ndf2.loc[(ndf2['Product'] == '34in Ultrawide Monitor') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
ultracmr21 = pd.to_numeric(ultramr2['Quantity Ordered'], errors='coerce')
ultracmr22 = pd.to_numeric(ultramr2['Price Each'], errors='coerce')
ultramr21 = (ultracmr21 * ultracmr22).sum().round(2)


thinkmr2l = ndf2.loc[(ndf2['Product'] == 'ThinkPad Laptop') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
thinkcmr21 = pd.to_numeric(thinkmr2l['Quantity Ordered'], errors='coerce')
thinkcmr22 = pd.to_numeric(thinkmr2l['Price Each'], errors='coerce')
thinklmr21 = (thinkcmr21 * thinkcmr22).sum().round(2)


lgmr2 = ndf2.loc[(ndf2['Product'] == 'LG Dryer') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
lgmrc21 = pd.to_numeric(lgmr2['Quantity Ordered'], errors='coerce')
lgmrc22 = pd.to_numeric(lgmr2['Price Each'], errors='coerce')
lgmr21 = (lgmrc21 * lgmrc22).sum().round(2)


lmmr2 = ndf2.loc[(ndf2['Product'] == 'LG Washing Machine') ^ (ndf2['Quantity Ordered'] == 1) ^ (ndf2['Price Each'] == 1)]
lmmrc21 = pd.to_numeric(lmmr2['Quantity Ordered'], errors='coerce')
lmmrc22 = pd.to_numeric(lmmr2['Price Each'], errors='coerce')
lmmr21 = (lmmrc21 * lmmrc22).sum().round(2)

#month 2 total:
m2tot = ippmr21+lggcabmr21+whphmr21+fhdmonmr21+aaamr21+gammonmr21+usbcccmr21+bosesmr21+applemr21+macbmr21+flatsmr21+varemr21+aamr21+googmr21+monmr21+ultramr21+thinklmr21+lgmr21+lmmr21
m2tot
# Out:
# 2203481.24

# %%
# new monthly rev calculations, month 3
ipmr3 = ndf3.loc[(ndf3['Product'] == 'iPhone') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] ==1)]
ipmrr31 = pd.to_numeric(ipmr3['Quantity Ordered'], errors='coerce')
ipmrr32 = pd.to_numeric(ipmr3['Price Each'], errors='coerce')
ippmr31 = (ipmrr31 * ipmrr32).sum().round(2)

lgcabmr3 = ndf3.loc[(ndf3['Product'] == 'Lightning Charging Cable') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
lgcabmr31 = pd.to_numeric(lgcabmr3['Quantity Ordered'], errors='coerce')
lgcabmr32 = pd.to_numeric(lgcabmr3['Price Each'], errors='coerce')
lggcabmr31 = (lgcabmr31 * lgcabmr32).sum().round(2)


whmr3 = ndf3.loc[(ndf3['Product'] == 'Wired Headphones') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
whmr31 = pd.to_numeric(whmr3['Quantity Ordered'], errors='coerce')
whmr32 = pd.to_numeric(whmr3['Price Each'], errors='coerce')
whphmr31 = (whmr31 * whmr32).sum().round(2)


fhmr3 = ndf3.loc[(ndf3['Product'] == '27in FHD Monitor') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
fhmr31 = pd.to_numeric(fhmr3['Quantity Ordered'], errors='coerce')
fhmr32 = pd.to_numeric(fhmr3['Price Each'], errors='coerce')
fhdmonmr31 = (fhmr31 * fhmr32).sum().round(2)


aaamr3 = ndf3.loc[(ndf3['Product'] == 'AAA Batteries (4-pack)') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
aaabmr31 = pd.to_numeric(aaamr3['Quantity Ordered'], errors='coerce')
aaabmr32 = pd.to_numeric(aaamr3['Price Each'], errors='coerce')
aaamr31 = (aaabmr31 * aaabmr32).sum().round(2)


gmmr3 = ndf3.loc[(ndf3['Product'] == '27in 4K Gaming Monitor') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
gmmr31 = pd.to_numeric(gmmr3['Quantity Ordered'], errors='coerce')
gmmr32 = pd.to_numeric(gmmr3['Price Each'], errors='coerce')
gammonmr31 = (gmmr31 * gmmr32).sum().round(2)


usmr3 = ndf3.loc[(ndf3['Product'] == 'USB-C Charging Cable') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
usmr31 = pd.to_numeric(usmr3['Quantity Ordered'], errors='coerce')
usmr32 = pd.to_numeric(usmr3['Price Each'], errors='coerce')
usbcccmr31 = (usmr31 * usmr32).sum().round(2)


bosesmr3 = ndf3.loc[(ndf3['Product'] == 'Bose SoundSport Headphones') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
bosecmr31 = pd.to_numeric(bosesmr3['Quantity Ordered'], errors='coerce')
bosecmr32 = pd.to_numeric(bosesmr3['Price Each'], errors='coerce')
bosesmr31 = (bosecmr31 * bosecmr32).sum().round(2)


applemr3 =  ndf3.loc[(ndf3['Product'] == 'Apple Airpods Headphones') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
applecmr31 = pd.to_numeric(applemr3['Quantity Ordered'], errors='coerce')
applecmr32 = pd.to_numeric(applemr3['Price Each'], errors='coerce')
applemr31 = (applecmr31 * applecmr32).sum().round(2)


macbmr3 = ndf3.loc[(ndf3['Product'] == 'Macbook Pro Laptop') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
maccmr31 = pd.to_numeric(macbmr3['Quantity Ordered'], errors='coerce')
maccmr32 = pd.to_numeric(macbmr3['Price Each'], errors='coerce')
macbmr31 = (maccmr31 * maccmr32).sum().round(2)


flatsmr3 = ndf3.loc[(ndf3['Product'] == 'Flatscreen TV') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
flatscmr31 = pd.to_numeric(flatsmr3['Quantity Ordered'], errors='coerce')
flatscmr32 = pd.to_numeric(flatsmr3['Price Each'], errors='coerce')
flatsmr31 = (flatscmr31 * flatscmr32).sum().round(2)


varemr3 = ndf3.loc[(ndf3['Product'] == 'Vareebadd Phone') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
varecmr31 = pd.to_numeric(varemr3['Quantity Ordered'], errors='coerce')
varecmr32 = pd.to_numeric(varemr3['Price Each'], errors='coerce')
varemr31 = (varecmr31 * varecmr32).sum().round(2)


aamr3 = ndf3.loc[(ndf3['Product'] == 'AA Batteries (4-pack)') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
aacmr31 = pd.to_numeric(aamr3['Quantity Ordered'], errors='coerce')
aacmr32 = pd.to_numeric(aamr3['Price Each'], errors='coerce')
aamr31 = (aacmr31 * aacmr32).sum().round(2)


googmr3 = ndf3.loc[(ndf3['Product'] == 'Google Phone') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
googcmr31 = pd.to_numeric(googmr3['Quantity Ordered'], errors='coerce')
googcmr32 = pd.to_numeric(googmr3['Price Each'], errors='coerce')
googmr31 = (googcmr31 * googcmr32).sum().round(2)


monmr3 = ndf3.loc[(ndf3['Product'] == '20in Monitor') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
moncmr31 = pd.to_numeric(monmr3['Quantity Ordered'], errors='coerce')
moncmr32 = pd.to_numeric(monmr3['Price Each'], errors='coerce')
monmr31 = (moncmr31 * moncmr32).sum().round(2)


ultramr3 = ndf3.loc[(ndf3['Product'] == '34in Ultrawide Monitor') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
ultracmr31 = pd.to_numeric(ultramr3['Quantity Ordered'], errors='coerce')
ultracmr32 = pd.to_numeric(ultramr3['Price Each'], errors='coerce')
ultramr31 = (ultracmr31 * ultracmr32).sum().round(2)


thinkmr3l = ndf3.loc[(ndf3['Product'] == 'ThinkPad Laptop') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
thinkcmr31 = pd.to_numeric(thinkmr3l['Quantity Ordered'], errors='coerce')
thinkcmr32 = pd.to_numeric(thinkmr3l['Price Each'], errors='coerce')
thinklmr31 = (thinkcmr31 * thinkcmr32).sum().round(2)


lgmr3 = ndf3.loc[(ndf3['Product'] == 'LG Dryer') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
lgmrc31 = pd.to_numeric(lgmr3['Quantity Ordered'], errors='coerce')
lgmrc32 = pd.to_numeric(lgmr3['Price Each'], errors='coerce')
lgmr31 = (lgmrc31 * lgmrc32).sum().round(2)


lmmr3 = ndf3.loc[(ndf3['Product'] == 'LG Washing Machine') ^ (ndf3['Quantity Ordered'] == 1) ^ (ndf3['Price Each'] == 1)]
lmmrc31 = pd.to_numeric(lmmr3['Quantity Ordered'], errors='coerce')
lmmrc32 = pd.to_numeric(lmmr3['Price Each'], errors='coerce')
lmmr31 = (lmmrc31 * lmmrc32).sum().round(2)

# month3 total:
m3tot=ippmr31+lggcabmr31+whphmr31+fhdmonmr31+aaamr31+gammonmr31+usbcccmr31+bosesmr31+applemr31+macbmr31+flatsmr31+varemr31+aamr31+googmr31+monmr31+ultramr31+thinklmr31+lgmr31+lmmr31
m3tot
# Out:
# 2809063.3000000003

# %%
# new monthly rev calculations, month 4
ipmr4 = ndf4.loc[(ndf4['Product'] == 'iPhone') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] ==1)]
ipmrr41 = pd.to_numeric(ipmr4['Quantity Ordered'], errors='coerce')
ipmrr42 = pd.to_numeric(ipmr4['Price Each'], errors='coerce')
ippmr41 = (ipmrr41 * ipmrr42).sum().round(2)

lgcabmr4 = ndf4.loc[(ndf4['Product'] == 'Lightning Charging Cable') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
lgcabmr41 = pd.to_numeric(lgcabmr4['Quantity Ordered'], errors='coerce')
lgcabmr42 = pd.to_numeric(lgcabmr4['Price Each'], errors='coerce')
lggcabmr41 = (lgcabmr41 * lgcabmr42).sum().round(2)


whmr4 = ndf4.loc[(ndf4['Product'] == 'Wired Headphones') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
whmr41 = pd.to_numeric(whmr4['Quantity Ordered'], errors='coerce')
whmr42 = pd.to_numeric(whmr4['Price Each'], errors='coerce')
whphmr41 = (whmr41 * whmr42).sum().round(2)


fhmr4 = ndf4.loc[(ndf4['Product'] == '27in FHD Monitor') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
fhmr41 = pd.to_numeric(fhmr4['Quantity Ordered'], errors='coerce')
fhmr42 = pd.to_numeric(fhmr4['Price Each'], errors='coerce')
fhdmonmr41 = (fhmr41 * fhmr42).sum().round(2)


aaamr4 = ndf4.loc[(ndf4['Product'] == 'AAA Batteries (4-pack)') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
aaabmr41 = pd.to_numeric(aaamr4['Quantity Ordered'], errors='coerce')
aaabmr42 = pd.to_numeric(aaamr4['Price Each'], errors='coerce')
aaamr41 = (aaabmr41 * aaabmr42).sum().round(2)


gmmr4 = ndf4.loc[(ndf4['Product'] == '27in 4K Gaming Monitor') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
gmmr41 = pd.to_numeric(gmmr4['Quantity Ordered'], errors='coerce')
gmmr42 = pd.to_numeric(gmmr4['Price Each'], errors='coerce')
gammonmr41 = (gmmr41 * gmmr42).sum().round(2)


usmr4 = ndf4.loc[(ndf4['Product'] == 'USB-C Charging Cable') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
usmr41 = pd.to_numeric(usmr4['Quantity Ordered'], errors='coerce')
usmr42 = pd.to_numeric(usmr4['Price Each'], errors='coerce')
usbcccmr41 = (usmr41 * usmr42).sum().round(2)


bosesmr4 = ndf4.loc[(ndf4['Product'] == 'Bose SoundSport Headphones') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
bosecmr41 = pd.to_numeric(bosesmr4['Quantity Ordered'], errors='coerce')
bosecmr42 = pd.to_numeric(bosesmr4['Price Each'], errors='coerce')
bosesmr41 = (bosecmr41 * bosecmr42).sum().round(2)


applemr4 =  ndf4.loc[(ndf4['Product'] == 'Apple Airpods Headphones') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
applecmr41 = pd.to_numeric(applemr4['Quantity Ordered'], errors='coerce')
applecmr42 = pd.to_numeric(applemr4['Price Each'], errors='coerce')
applemr41 = (applecmr41 * applecmr42).sum().round(2)


macbmr4 = ndf4.loc[(ndf4['Product'] == 'Macbook Pro Laptop') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
maccmr41 = pd.to_numeric(macbmr4['Quantity Ordered'], errors='coerce')
maccmr42 = pd.to_numeric(macbmr4['Price Each'], errors='coerce')
macbmr41 = (maccmr41 * maccmr42).sum().round(2)


flatsmr4 = ndf4.loc[(ndf4['Product'] == 'Flatscreen TV') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
flatscmr41 = pd.to_numeric(flatsmr4['Quantity Ordered'], errors='coerce')
flatscmr42 = pd.to_numeric(flatsmr4['Price Each'], errors='coerce')
flatsmr41 = (flatscmr41 * flatscmr42).sum().round(2)


varemr4 = ndf4.loc[(ndf4['Product'] == 'Vareebadd Phone') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
varecmr41 = pd.to_numeric(varemr4['Quantity Ordered'], errors='coerce')
varecmr42 = pd.to_numeric(varemr4['Price Each'], errors='coerce')
varemr41 = (varecmr41 * varecmr42).sum().round(2)


aamr4 = ndf4.loc[(ndf4['Product'] == 'AA Batteries (4-pack)') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
aacmr41 = pd.to_numeric(aamr4['Quantity Ordered'], errors='coerce')
aacmr42 = pd.to_numeric(aamr4['Price Each'], errors='coerce')
aamr41 = (aacmr41 * aacmr42).sum().round(2)


googmr4 = ndf4.loc[(ndf4['Product'] == 'Google Phone') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
googcmr41 = pd.to_numeric(googmr4['Quantity Ordered'], errors='coerce')
googcmr42 = pd.to_numeric(googmr4['Price Each'], errors='coerce')
googmr41 = (googcmr41 * googcmr42).sum().round(2)


monmr4 = ndf4.loc[(ndf4['Product'] == '20in Monitor') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
moncmr41 = pd.to_numeric(monmr4['Quantity Ordered'], errors='coerce')
moncmr42 = pd.to_numeric(monmr4['Price Each'], errors='coerce')
monmr41 = (moncmr41 * moncmr42).sum().round(2)


ultramr4 = ndf4.loc[(ndf4['Product'] == '34in Ultrawide Monitor') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
ultracmr41 = pd.to_numeric(ultramr4['Quantity Ordered'], errors='coerce')
ultracmr42 = pd.to_numeric(ultramr4['Price Each'], errors='coerce')
ultramr41 = (ultracmr41 * ultracmr42).sum().round(2)


thinkmr4l = ndf4.loc[(ndf4['Product'] == 'ThinkPad Laptop') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
thinkcmr41 = pd.to_numeric(thinkmr4l['Quantity Ordered'], errors='coerce')
thinkcmr42 = pd.to_numeric(thinkmr4l['Price Each'], errors='coerce')
thinklmr41 = (thinkcmr41 * thinkcmr42).sum().round(2)


lgmr4 = ndf4.loc[(ndf4['Product'] == 'LG Dryer') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
lgmrc41 = pd.to_numeric(lgmr4['Quantity Ordered'], errors='coerce')
lgmrc42 = pd.to_numeric(lgmr4['Price Each'], errors='coerce')
lgmr41 = (lgmrc41 * lgmrc42).sum().round(2)


lmmr4 = ndf4.loc[(ndf4['Product'] == 'LG Washing Machine') ^ (ndf4['Quantity Ordered'] == 1) ^ (ndf4['Price Each'] == 1)]
lmmrc41 = pd.to_numeric(lmmr4['Quantity Ordered'], errors='coerce')
lmmrc42 = pd.to_numeric(lmmr4['Price Each'], errors='coerce')
lmmr41 = (lmmrc41 * lmmrc42).sum().round(2)

#month4 total:
m4tot=ippmr41+lggcabmr41+whphmr41+fhdmonmr41+aaamr41+gammonmr41+usbcccmr41+bosesmr41+applemr41+macbmr41+flatsmr41+varemr41+aamr41+googmr41+monmr41+ultramr41+thinklmr41+lgmr41+lmmr41
m4tot
# Out:
# 3396059.1100000003

# %%
# new monthly rev calculations, month 5
ipmr5 = ndf5.loc[(ndf5['Product'] == 'iPhone') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] ==1)]
ipmrr51 = pd.to_numeric(ipmr5['Quantity Ordered'], errors='coerce')
ipmrr52 = pd.to_numeric(ipmr5['Price Each'], errors='coerce')
ippmr51 = (ipmrr51 * ipmrr52).sum().round(2)

lgcabmr5 = ndf5.loc[(ndf5['Product'] == 'Lightning Charging Cable') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
lgcabmr51 = pd.to_numeric(lgcabmr5['Quantity Ordered'], errors='coerce')
lgcabmr52 = pd.to_numeric(lgcabmr5['Price Each'], errors='coerce')
lggcabmr51 = (lgcabmr51 * lgcabmr52).sum().round(2)


whmr5 = ndf5.loc[(ndf5['Product'] == 'Wired Headphones') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
whmr51 = pd.to_numeric(whmr5['Quantity Ordered'], errors='coerce')
whmr52 = pd.to_numeric(whmr5['Price Each'], errors='coerce')
whphmr51 = (whmr51 * whmr52).sum().round(2)


fhmr5 = ndf5.loc[(ndf5['Product'] == '27in FHD Monitor') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
fhmr51 = pd.to_numeric(fhmr5['Quantity Ordered'], errors='coerce')
fhmr52 = pd.to_numeric(fhmr5['Price Each'], errors='coerce')
fhdmonmr51 = (fhmr51 * fhmr52).sum().round(2)


aaamr5 = ndf5.loc[(ndf5['Product'] == 'AAA Batteries (4-pack)') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
aaabmr51 = pd.to_numeric(aaamr5['Quantity Ordered'], errors='coerce')
aaabmr52 = pd.to_numeric(aaamr5['Price Each'], errors='coerce')
aaamr51 = (aaabmr51 * aaabmr52).sum().round(2)


gmmr5 = ndf5.loc[(ndf5['Product'] == '27in 4K Gaming Monitor') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
gmmr51 = pd.to_numeric(gmmr5['Quantity Ordered'], errors='coerce')
gmmr52 = pd.to_numeric(gmmr5['Price Each'], errors='coerce')
gammonmr51 = (gmmr51 * gmmr52).sum().round(2)


usmr5 = ndf5.loc[(ndf5['Product'] == 'USB-C Charging Cable') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
usmr51 = pd.to_numeric(usmr5['Quantity Ordered'], errors='coerce')
usmr52 = pd.to_numeric(usmr5['Price Each'], errors='coerce')
usbcccmr51 = (usmr51 * usmr52).sum().round(2)


bosesmr5 = ndf5.loc[(ndf5['Product'] == 'Bose SoundSport Headphones') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
bosecmr51 = pd.to_numeric(bosesmr5['Quantity Ordered'], errors='coerce')
bosecmr52 = pd.to_numeric(bosesmr5['Price Each'], errors='coerce')
bosesmr51 = (bosecmr51 * bosecmr52).sum().round(2)


applemr5 =  ndf5.loc[(ndf5['Product'] == 'Apple Airpods Headphones') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
applecmr51 = pd.to_numeric(applemr5['Quantity Ordered'], errors='coerce')
applecmr52 = pd.to_numeric(applemr5['Price Each'], errors='coerce')
applemr51 = (applecmr51 * applecmr52).sum().round(2)


macbmr5 = ndf5.loc[(ndf5['Product'] == 'Macbook Pro Laptop') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
maccmr51 = pd.to_numeric(macbmr5['Quantity Ordered'], errors='coerce')
maccmr52 = pd.to_numeric(macbmr5['Price Each'], errors='coerce')
macbmr51 = (maccmr51 * maccmr52).sum().round(2)


flatsmr5 = ndf5.loc[(ndf5['Product'] == 'Flatscreen TV') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
flatscmr51 = pd.to_numeric(flatsmr5['Quantity Ordered'], errors='coerce')
flatscmr52 = pd.to_numeric(flatsmr5['Price Each'], errors='coerce')
flatsmr51 = (flatscmr51 * flatscmr52).sum().round(2)


varemr5 = ndf5.loc[(ndf5['Product'] == 'Vareebadd Phone') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
varecmr51 = pd.to_numeric(varemr5['Quantity Ordered'], errors='coerce')
varecmr52 = pd.to_numeric(varemr5['Price Each'], errors='coerce')
varemr51 = (varecmr51 * varecmr52).sum().round(2)


aamr5 = ndf5.loc[(ndf5['Product'] == 'AA Batteries (4-pack)') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
aacmr51 = pd.to_numeric(aamr5['Quantity Ordered'], errors='coerce')
aacmr52 = pd.to_numeric(aamr5['Price Each'], errors='coerce')
aamr51 = (aacmr51 * aacmr52).sum().round(2)


googmr5 = ndf5.loc[(ndf5['Product'] == 'Google Phone') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
googcmr51 = pd.to_numeric(googmr5['Quantity Ordered'], errors='coerce')
googcmr52 = pd.to_numeric(googmr5['Price Each'], errors='coerce')
googmr51 = (googcmr51 * googcmr52).sum().round(2)


monmr5 = ndf5.loc[(ndf5['Product'] == '20in Monitor') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
moncmr51 = pd.to_numeric(monmr5['Quantity Ordered'], errors='coerce')
moncmr52 = pd.to_numeric(monmr5['Price Each'], errors='coerce')
monmr51 = (moncmr51 * moncmr52).sum().round(2)


ultramr5 = ndf5.loc[(ndf5['Product'] == '34in Ultrawide Monitor') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
ultracmr51 = pd.to_numeric(ultramr5['Quantity Ordered'], errors='coerce')
ultracmr52 = pd.to_numeric(ultramr5['Price Each'], errors='coerce')
ultramr51 = (ultracmr51 * ultracmr52).sum().round(2)


thinkmr5l = ndf5.loc[(ndf5['Product'] == 'ThinkPad Laptop') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
thinkcmr51 = pd.to_numeric(thinkmr5l['Quantity Ordered'], errors='coerce')
thinkcmr52 = pd.to_numeric(thinkmr5l['Price Each'], errors='coerce')
thinklmr51 = (thinkcmr51 * thinkcmr52).sum().round(2)


lgmr5 = ndf5.loc[(ndf5['Product'] == 'LG Dryer') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
lgmrc51 = pd.to_numeric(lgmr5['Quantity Ordered'], errors='coerce')
lgmrc52 = pd.to_numeric(lgmr5['Price Each'], errors='coerce')
lgmr51 = (lgmrc51 * lgmrc52).sum().round(2)


lmmr5 = ndf5.loc[(ndf5['Product'] == 'LG Washing Machine') ^ (ndf5['Quantity Ordered'] == 1) ^ (ndf5['Price Each'] == 1)]
lmmrc51 = pd.to_numeric(lmmr5['Quantity Ordered'], errors='coerce')
lmmrc52 = pd.to_numeric(lmmr5['Price Each'], errors='coerce')
lmmr51 = (lmmrc51 * lmmrc52).sum().round(2)

# month5 total:
m5tot=ippmr51+lggcabmr51+whphmr51+fhdmonmr51+aaamr51+gammonmr51+usbcccmr51+bosesmr51+applemr51+macbmr51+flatsmr51 + varemr51+aamr51+googmr51+monmr51+ultramr51+thinklmr51+lgmr51+lmmr51
m5tot
# Out:
# 3144584.8000000003

# %%
# new monthly rev calculations, month 6 
ipmr6 = ndf6.loc[(ndf6['Product'] == 'iPhone') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] ==1)]
ipmrr61 = pd.to_numeric(ipmr6['Quantity Ordered'], errors='coerce')
ipmrr62 = pd.to_numeric(ipmr6['Price Each'], errors='coerce')
ippmr61 = (ipmrr61 * ipmrr62).sum().round(2)

lgcabmr6 = ndf6.loc[(ndf6['Product'] == 'Lightning Charging Cable') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
lgcabmr61 = pd.to_numeric(lgcabmr6['Quantity Ordered'], errors='coerce')
lgcabmr62 = pd.to_numeric(lgcabmr6['Price Each'], errors='coerce')
lggcabmr61 = (lgcabmr61 * lgcabmr62).sum().round(2)


whmr6 = ndf6.loc[(ndf6['Product'] == 'Wired Headphones') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
whmr61 = pd.to_numeric(whmr6['Quantity Ordered'], errors='coerce')
whmr62 = pd.to_numeric(whmr6['Price Each'], errors='coerce')
whphmr61 = (whmr61 * whmr62).sum().round(2)


fhmr6 = ndf6.loc[(ndf6['Product'] == '27in FHD Monitor') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
fhmr61 = pd.to_numeric(fhmr6['Quantity Ordered'], errors='coerce')
fhmr62 = pd.to_numeric(fhmr6['Price Each'], errors='coerce')
fhdmonmr61 = (fhmr61 * fhmr62).sum().round(2)


aaamr6 = ndf6.loc[(ndf6['Product'] == 'AAA Batteries (4-pack)') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
aaabmr61 = pd.to_numeric(aaamr6['Quantity Ordered'], errors='coerce')
aaabmr62 = pd.to_numeric(aaamr6['Price Each'], errors='coerce')
aaamr61 = (aaabmr61 * aaabmr62).sum().round(2)


gmmr6 = ndf6.loc[(ndf6['Product'] == '27in 4K Gaming Monitor') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
gmmr61 = pd.to_numeric(gmmr6['Quantity Ordered'], errors='coerce')
gmmr62 = pd.to_numeric(gmmr6['Price Each'], errors='coerce')
gammonmr61 = (gmmr61 * gmmr62).sum().round(2)


usmr6 = ndf6.loc[(ndf6['Product'] == 'USB-C Charging Cable') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
usmr61 = pd.to_numeric(usmr6['Quantity Ordered'], errors='coerce')
usmr62 = pd.to_numeric(usmr6['Price Each'], errors='coerce')
usbcccmr61 = (usmr61 * usmr62).sum().round(2)


bosesmr6 = ndf6.loc[(ndf6['Product'] == 'Bose SoundSport Headphones') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
bosecmr61 = pd.to_numeric(bosesmr6['Quantity Ordered'], errors='coerce')
bosecmr62 = pd.to_numeric(bosesmr6['Price Each'], errors='coerce')
bosesmr61 = (bosecmr61 * bosecmr62).sum().round(2)


applemr6 =  ndf6.loc[(ndf6['Product'] == 'Apple Airpods Headphones') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
applecmr61 = pd.to_numeric(applemr6['Quantity Ordered'], errors='coerce')
applecmr62 = pd.to_numeric(applemr6['Price Each'], errors='coerce')
applemr61 = (applecmr61 * applecmr62).sum().round(2)


macbmr6 = ndf6.loc[(ndf6['Product'] == 'Macbook Pro Laptop') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
maccmr61 = pd.to_numeric(macbmr6['Quantity Ordered'], errors='coerce')
maccmr62 = pd.to_numeric(macbmr6['Price Each'], errors='coerce')
macbmr61 = (maccmr61 * maccmr62).sum().round(2)


flatsmr6 = ndf6.loc[(ndf6['Product'] == 'Flatscreen TV') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
flatscmr61 = pd.to_numeric(flatsmr6['Quantity Ordered'], errors='coerce')
flatscmr62 = pd.to_numeric(flatsmr6['Price Each'], errors='coerce')
flatsmr61 = (flatscmr61 * flatscmr62).sum().round(2)


varemr6 = ndf6.loc[(ndf6['Product'] == 'Vareebadd Phone') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
varecmr61 = pd.to_numeric(varemr6['Quantity Ordered'], errors='coerce')
varecmr62 = pd.to_numeric(varemr6['Price Each'], errors='coerce')
varemr61 = (varecmr61 * varecmr62).sum().round(2)


aamr6 = ndf6.loc[(ndf6['Product'] == 'AA Batteries (4-pack)') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
aacmr61 = pd.to_numeric(aamr6['Quantity Ordered'], errors='coerce')
aacmr62 = pd.to_numeric(aamr6['Price Each'], errors='coerce')
aamr61 = (aacmr61 * aacmr62).sum().round(2)


googmr6 = ndf6.loc[(ndf6['Product'] == 'Google Phone') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
googcmr61 = pd.to_numeric(googmr6['Quantity Ordered'], errors='coerce')
googcmr62 = pd.to_numeric(googmr6['Price Each'], errors='coerce')
googmr61 = (googcmr61 * googcmr62).sum().round(2)


monmr6 = ndf6.loc[(ndf6['Product'] == '20in Monitor') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
moncmr61 = pd.to_numeric(monmr6['Quantity Ordered'], errors='coerce')
moncmr62 = pd.to_numeric(monmr6['Price Each'], errors='coerce')
monmr61 = (moncmr61 * moncmr62).sum().round(2)


ultramr6 = ndf6.loc[(ndf6['Product'] == '34in Ultrawide Monitor') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
ultracmr61 = pd.to_numeric(ultramr6['Quantity Ordered'], errors='coerce')
ultracmr62 = pd.to_numeric(ultramr6['Price Each'], errors='coerce')
ultramr61 = (ultracmr61 * ultracmr62).sum().round(2)


thinkmr6l = ndf6.loc[(ndf6['Product'] == 'ThinkPad Laptop') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
thinkcmr61 = pd.to_numeric(thinkmr6l['Quantity Ordered'], errors='coerce')
thinkcmr62 = pd.to_numeric(thinkmr6l['Price Each'], errors='coerce')
thinklmr61 = (thinkcmr61 * thinkcmr62).sum().round(2)


lgmr6 = ndf6.loc[(ndf6['Product'] == 'LG Dryer') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
lgmrc61 = pd.to_numeric(lgmr6['Quantity Ordered'], errors='coerce')
lgmrc62 = pd.to_numeric(lgmr6['Price Each'], errors='coerce')
lgmr61 = (lgmrc61 * lgmrc62).sum().round(2)


lmmr6 = ndf6.loc[(ndf6['Product'] == 'LG Washing Machine') ^ (ndf6['Quantity Ordered'] == 1) ^ (ndf6['Price Each'] == 1)]
lmmrc61 = pd.to_numeric(lmmr6['Quantity Ordered'], errors='coerce')
lmmrc62 = pd.to_numeric(lmmr6['Price Each'], errors='coerce')
lmmr61 = (lmmrc61 * lmmrc62).sum().round(2)

# month 6 total:
m6tot=ippmr61+lggcabmr61+whphmr61+fhdmonmr61+aaamr61+gammonmr61+usbcccmr61+bosesmr61+applemr61+macbmr61+flatsmr61+varemr61+aamr61+googmr61+monmr61+ultramr61+thinklmr61+lgmr61+lmmr61
m6tot
# Out:
# 2578293.3000000003

# %%
# new monthly re calculations, month 7
ipmr7 = ndf7.loc[(ndf7['Product'] == 'iPhone') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] ==1)]
ipmrr71 = pd.to_numeric(ipmr7['Quantity Ordered'], errors='coerce')
ipmrr72 = pd.to_numeric(ipmr7['Price Each'], errors='coerce')
ippmr71 = (ipmrr71 * ipmrr72).sum().round(2)

lgcabmr7 = ndf7.loc[(ndf7['Product'] == 'Lightning Charging Cable') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
lgcabmr71 = pd.to_numeric(lgcabmr7['Quantity Ordered'], errors='coerce')
lgcabmr72 = pd.to_numeric(lgcabmr7['Price Each'], errors='coerce')
lggcabmr71 = (lgcabmr71 * lgcabmr72).sum().round(2)


whmr7 = ndf7.loc[(ndf7['Product'] == 'Wired Headphones') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
whmr71 = pd.to_numeric(whmr7['Quantity Ordered'], errors='coerce')
whmr72 = pd.to_numeric(whmr7['Price Each'], errors='coerce')
whphmr71 = (whmr71 * whmr72).sum().round(2)


fhmr7 = ndf7.loc[(ndf7['Product'] == '27in FHD Monitor') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
fhmr71 = pd.to_numeric(fhmr7['Quantity Ordered'], errors='coerce')
fhmr72 = pd.to_numeric(fhmr7['Price Each'], errors='coerce')
fhdmonmr71 = (fhmr71 * fhmr72).sum().round(2)


aaamr7 = ndf7.loc[(ndf7['Product'] == 'AAA Batteries (4-pack)') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
aaabmr71 = pd.to_numeric(aaamr7['Quantity Ordered'], errors='coerce')
aaabmr72 = pd.to_numeric(aaamr7['Price Each'], errors='coerce')
aaamr71 = (aaabmr71 * aaabmr72).sum().round(2)


gmmr7 = ndf7.loc[(ndf7['Product'] == '27in 4K Gaming Monitor') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
gmmr71 = pd.to_numeric(gmmr7['Quantity Ordered'], errors='coerce')
gmmr72 = pd.to_numeric(gmmr7['Price Each'], errors='coerce')
gammonmr71 = (gmmr71 * gmmr72).sum().round(2)


usmr7 = ndf7.loc[(ndf7['Product'] == 'USB-C Charging Cable') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
usmr71 = pd.to_numeric(usmr7['Quantity Ordered'], errors='coerce')
usmr72 = pd.to_numeric(usmr7['Price Each'], errors='coerce')
usbcccmr71 = (usmr71 * usmr72).sum().round(2)


bosesmr7 = ndf7.loc[(ndf7['Product'] == 'Bose SoundSport Headphones') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] ==1)]
bosecmr71 = pd.to_numeric(bosesmr7['Quantity Ordered'], errors='coerce')
bosecmr72 = pd.to_numeric(bosesmr7['Price Each'], errors='coerce')
bosesmr71 = (bosecmr71 * bosecmr72).sum().round(2)


applemr7 =  ndf7.loc[(ndf7['Product'] == 'Apple Airpods Headphones') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
applecmr71 = pd.to_numeric(applemr7['Quantity Ordered'], errors='coerce')
applecmr72 = pd.to_numeric(applemr7['Price Each'], errors='coerce')
applemr71 = (applecmr71 * applecmr72).sum().round(2)


macbmr7 = ndf7.loc[(ndf7['Product'] == 'Macbook Pro Laptop') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
maccmr71 = pd.to_numeric(macbmr7['Quantity Ordered'], errors='coerce')
maccmr72 = pd.to_numeric(macbmr7['Price Each'], errors='coerce')
macbmr71 = (maccmr71 * maccmr72).sum().round(2)


flatsmr7 = ndf7.loc[(ndf7['Product'] == 'Flatscreen TV') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
flatscmr71 = pd.to_numeric(flatsmr7['Quantity Ordered'], errors='coerce')
flatscmr72 = pd.to_numeric(flatsmr7['Price Each'], errors='coerce')
flatsmr71 = (flatscmr71 * flatscmr72).sum().round(2)


varemr7 = ndf7.loc[(ndf7['Product'] == 'Vareebadd Phone') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
varecmr71 = pd.to_numeric(varemr7['Quantity Ordered'], errors='coerce')
varecmr72 = pd.to_numeric(varemr7['Price Each'], errors='coerce')
varemr71 = (varecmr71 * varecmr72).sum().round(2)


aamr7 = ndf7.loc[(ndf7['Product'] == 'AA Batteries (4-pack)') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
aacmr71 = pd.to_numeric(aamr7['Quantity Ordered'], errors='coerce')
aacmr72 = pd.to_numeric(aamr7['Price Each'], errors='coerce')
aamr71 = (aacmr71 * aacmr72).sum().round(2)


googmr7 = ndf7.loc[(ndf7['Product'] == 'Google Phone') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
googcmr71 = pd.to_numeric(googmr7['Quantity Ordered'], errors='coerce')
googcmr72 = pd.to_numeric(googmr7['Price Each'], errors='coerce')
googmr71 = (googcmr71 * googcmr72).sum().round(2)


monmr7 = ndf7.loc[(ndf7['Product'] == '20in Monitor') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
moncmr71 = pd.to_numeric(monmr7['Quantity Ordered'], errors='coerce')
moncmr72 = pd.to_numeric(monmr7['Price Each'], errors='coerce')
monmr71 = (moncmr71 * moncmr72).sum().round(2)


ultramr7 = ndf7.loc[(ndf7['Product'] == '34in Ultrawide Monitor') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
ultracmr71 = pd.to_numeric(ultramr7['Quantity Ordered'], errors='coerce')
ultracmr72 = pd.to_numeric(ultramr7['Price Each'], errors='coerce')
ultramr71 = (ultracmr71 * ultracmr72).sum().round(2)


thinkmr7l = ndf7.loc[(ndf7['Product'] == 'ThinkPad Laptop') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
thinkcmr71 = pd.to_numeric(thinkmr7l['Quantity Ordered'], errors='coerce')
thinkcmr72 = pd.to_numeric(thinkmr7l['Price Each'], errors='coerce')
thinklmr71 = (thinkcmr71 * thinkcmr72).sum().round(2)


lgmr7 = ndf7.loc[(ndf7['Product'] == 'LG Dryer') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
lgmrc71 = pd.to_numeric(lgmr7['Quantity Ordered'], errors='coerce')
lgmrc72 = pd.to_numeric(lgmr7['Price Each'], errors='coerce')
lgmr71 = (lgmrc71 * lgmrc72).sum().round(2)


lmmr7 = ndf7.loc[(ndf7['Product'] == 'LG Washing Machine') ^ (ndf7['Quantity Ordered'] == 1) ^ (ndf7['Price Each'] == 1)]
lmmrc71 = pd.to_numeric(lmmr7['Quantity Ordered'], errors='coerce')
lmmrc72 = pd.to_numeric(lmmr7['Price Each'], errors='coerce')
lmmr71 = (lmmrc71 * lmmrc72).sum().round(2)

# month 7 total:
m7tot=ippmr71+lggcabmr71+whphmr71+fhdmonmr71+aaamr71+gammonmr71+usbcccmr71+bosesmr71+applemr71+macbmr71+flatsmr71+varemr71+aamr71+googmr71+monmr71+ultramr71+thinklmr71+lgmr71+lmmr71
m7tot
# Out:
# 2646899.69

# %%
# new monthly rev calculations, month 8
ipmr8 = ndf8.loc[(ndf8['Product'] == 'iPhone') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] ==1)]
ipmrr81 = pd.to_numeric(ipmr8['Quantity Ordered'], errors='coerce')
ipmrr82 = pd.to_numeric(ipmr8['Price Each'], errors='coerce')
ippmr81 = (ipmrr81 * ipmrr82).sum().round(2)

lgcabmr8 = ndf8.loc[(ndf8['Product'] == 'Lightning Charging Cable') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
lgcabmr81 = pd.to_numeric(lgcabmr8['Quantity Ordered'], errors='coerce')
lgcabmr82 = pd.to_numeric(lgcabmr8['Price Each'], errors='coerce')
lggcabmr81 = (lgcabmr81 * lgcabmr82).sum().round(2)


whmr8 = ndf8.loc[(ndf8['Product'] == 'Wired Headphones') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
whmr81 = pd.to_numeric(whmr8['Quantity Ordered'], errors='coerce')
whmr82 = pd.to_numeric(whmr8['Price Each'], errors='coerce')
whphmr81 = (whmr81 * whmr82).sum().round(2)


fhmr8 = ndf8.loc[(ndf8['Product'] == '27in FHD Monitor') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
fhmr81 = pd.to_numeric(fhmr8['Quantity Ordered'], errors='coerce')
fhmr82 = pd.to_numeric(fhmr8['Price Each'], errors='coerce')
fhdmonmr81 = (fhmr81 * fhmr82).sum().round(2)


aaamr8 = ndf8.loc[(ndf8['Product'] == 'AAA Batteries (4-pack)') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
aaabmr81 = pd.to_numeric(aaamr8['Quantity Ordered'], errors='coerce')
aaabmr82 = pd.to_numeric(aaamr8['Price Each'], errors='coerce')
aaamr81 = (aaabmr81 * aaabmr82).sum().round(2)


gmmr8 = ndf8.loc[(ndf8['Product'] == '27in 4K Gaming Monitor') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
gmmr81 = pd.to_numeric(gmmr8['Quantity Ordered'], errors='coerce')
gmmr82 = pd.to_numeric(gmmr8['Price Each'], errors='coerce')
gammonmr81 = (gmmr81 * gmmr82).sum().round(2)


usmr8 = ndf8.loc[(ndf8['Product'] == 'USB-C Charging Cable') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
usmr81 = pd.to_numeric(usmr8['Quantity Ordered'], errors='coerce')
usmr82 = pd.to_numeric(usmr8['Price Each'], errors='coerce')
usbcccmr81 = (usmr81 * usmr82).sum().round(2)


bosesmr8 = ndf8.loc[(ndf8['Product'] == 'Bose SoundSport Headphones') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] ==1)]
bosecmr81 = pd.to_numeric(bosesmr8['Quantity Ordered'], errors='coerce')
bosecmr82 = pd.to_numeric(bosesmr8['Price Each'], errors='coerce')
bosesmr81 = (bosecmr81 * bosecmr82).sum().round(2)


applemr8 =  ndf8.loc[(ndf8['Product'] == 'Apple Airpods Headphones') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
applecmr81 = pd.to_numeric(applemr8['Quantity Ordered'], errors='coerce')
applecmr82 = pd.to_numeric(applemr8['Price Each'], errors='coerce')
applemr81 = (applecmr81 * applecmr82).sum().round(2)


macbmr8 = ndf8.loc[(ndf8['Product'] == 'Macbook Pro Laptop') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
maccmr81 = pd.to_numeric(macbmr8['Quantity Ordered'], errors='coerce')
maccmr82 = pd.to_numeric(macbmr8['Price Each'], errors='coerce')
macbmr81 = (maccmr81 * maccmr82).sum().round(2)


flatsmr8 = ndf8.loc[(ndf8['Product'] == 'Flatscreen TV') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
flatscmr81 = pd.to_numeric(flatsmr8['Quantity Ordered'], errors='coerce')
flatscmr82 = pd.to_numeric(flatsmr8['Price Each'], errors='coerce')
flatsmr81 = (flatscmr81 * flatscmr82).sum().round(2)


varemr8 = ndf8.loc[(ndf8['Product'] == 'Vareebadd Phone') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
varecmr81 = pd.to_numeric(varemr8['Quantity Ordered'], errors='coerce')
varecmr82 = pd.to_numeric(varemr8['Price Each'], errors='coerce')
varemr81 = (varecmr81 * varecmr82).sum().round(2)


aamr8 = ndf8.loc[(ndf8['Product'] == 'AA Batteries (4-pack)') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
aacmr81 = pd.to_numeric(aamr8['Quantity Ordered'], errors='coerce')
aacmr82 = pd.to_numeric(aamr8['Price Each'], errors='coerce')
aamr81 = (aacmr81 * aacmr82).sum().round(2)


googmr8 = ndf8.loc[(ndf8['Product'] == 'Google Phone') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
googcmr81 = pd.to_numeric(googmr8['Quantity Ordered'], errors='coerce')
googcmr82 = pd.to_numeric(googmr8['Price Each'], errors='coerce')
googmr81 = (googcmr81 * googcmr82).sum().round(2)


monmr8 = ndf8.loc[(ndf8['Product'] == '20in Monitor') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
moncmr81 = pd.to_numeric(monmr8['Quantity Ordered'], errors='coerce')
moncmr82 = pd.to_numeric(monmr8['Price Each'], errors='coerce')
monmr81 = (moncmr81 * moncmr82).sum().round(2)


ultramr8 = ndf8.loc[(ndf8['Product'] == '34in Ultrawide Monitor') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
ultracmr81 = pd.to_numeric(ultramr8['Quantity Ordered'], errors='coerce')
ultracmr82 = pd.to_numeric(ultramr8['Price Each'], errors='coerce')
ultramr81 = (ultracmr81 * ultracmr82).sum().round(2)


thinkmr8l = ndf8.loc[(ndf8['Product'] == 'ThinkPad Laptop') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
thinkcmr81 = pd.to_numeric(thinkmr8l['Quantity Ordered'], errors='coerce')
thinkcmr82 = pd.to_numeric(thinkmr8l['Price Each'], errors='coerce')
thinklmr81 = (thinkcmr81 * thinkcmr82).sum().round(2)


lgmr8 = ndf8.loc[(ndf8['Product'] == 'LG Dryer') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
lgmrc81 = pd.to_numeric(lgmr8['Quantity Ordered'], errors='coerce')
lgmrc82 = pd.to_numeric(lgmr8['Price Each'], errors='coerce')
lgmr81 = (lgmrc81 * lgmrc82).sum().round(2)


lmmr8 = ndf8.loc[(ndf8['Product'] == 'LG Washing Machine') ^ (ndf8['Quantity Ordered'] == 1) ^ (ndf8['Price Each'] == 1)]
lmmrc81 = pd.to_numeric(lmmr8['Quantity Ordered'], errors='coerce')
lmmrc82 = pd.to_numeric(lmmr8['Price Each'], errors='coerce')
lmmr81 = (lmmrc81 * lmmrc82).sum().round(2)

# month 8 total:
m8tot= ippmr81+lggcabmr81+whphmr81+fhdmonmr81+aaamr81+gammonmr81+usbcccmr81+bosesmr81+applemr81+macbmr81+flatsmr81+varemr81+aamr81+googmr81+monmr81+ultramr81+thinklmr81+lgmr81+lmmr81
m8tot
# Out:
# 2244412.3099999996

# %%
# new monthly rev calculations, month 9
ipmr9 = ndf9.loc[(ndf9['Product'] == 'iPhone') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] ==1)]
ipmrr91 = pd.to_numeric(ipmr9['Quantity Ordered'], errors='coerce')
ipmrr92 = pd.to_numeric(ipmr9['Price Each'], errors='coerce')
ippmr91 = (ipmrr91 * ipmrr92).sum().round(2)

lgcabmr9 = ndf9.loc[(ndf9['Product'] == 'Lightning Charging Cable') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
lgcabmr91 = pd.to_numeric(lgcabmr9['Quantity Ordered'], errors='coerce')
lgcabmr92 = pd.to_numeric(lgcabmr9['Price Each'], errors='coerce')
lggcabmr91 = (lgcabmr91 * lgcabmr92).sum().round(2)


whmr9 = ndf9.loc[(ndf9['Product'] == 'Wired Headphones') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
whmr91 = pd.to_numeric(whmr9['Quantity Ordered'], errors='coerce')
whmr92 = pd.to_numeric(whmr9['Price Each'], errors='coerce')
whphmr91 = (whmr91 * whmr92).sum().round(2)


fhmr9 = ndf9.loc[(ndf9['Product'] == '27in FHD Monitor') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
fhmr91 = pd.to_numeric(fhmr9['Quantity Ordered'], errors='coerce')
fhmr92 = pd.to_numeric(fhmr9['Price Each'], errors='coerce')
fhdmonmr91 = (fhmr91 * fhmr92).sum().round(2)


aaamr9 = ndf9.loc[(ndf9['Product'] == 'AAA Batteries (4-pack)') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
aaabmr91 = pd.to_numeric(aaamr9['Quantity Ordered'], errors='coerce')
aaabmr92 = pd.to_numeric(aaamr9['Price Each'], errors='coerce')
aaamr91 = (aaabmr91 * aaabmr92).sum().round(2)


gmmr9 = ndf9.loc[(ndf9['Product'] == '27in 4K Gaming Monitor') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
gmmr91 = pd.to_numeric(gmmr9['Quantity Ordered'], errors='coerce')
gmmr92 = pd.to_numeric(gmmr9['Price Each'], errors='coerce')
gammonmr91 = (gmmr91 * gmmr92).sum().round(2)


usmr9 = ndf9.loc[(ndf9['Product'] == 'USB-C Charging Cable') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
usmr91 = pd.to_numeric(usmr9['Quantity Ordered'], errors='coerce')
usmr92 = pd.to_numeric(usmr9['Price Each'], errors='coerce')
usbcccmr91 = (usmr91 * usmr92).sum().round(2)


bosesmr9 = ndf9.loc[(ndf9['Product'] == 'Bose SoundSport Headphones') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] ==1)]
bosecmr91 = pd.to_numeric(bosesmr9['Quantity Ordered'], errors='coerce')
bosecmr92 = pd.to_numeric(bosesmr9['Price Each'], errors='coerce')
bosesmr91 = (bosecmr91 * bosecmr92).sum().round(2)


applemr9 =  ndf9.loc[(ndf9['Product'] == 'Apple Airpods Headphones') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
applecmr91 = pd.to_numeric(applemr9['Quantity Ordered'], errors='coerce')
applecmr92 = pd.to_numeric(applemr9['Price Each'], errors='coerce')
applemr91 = (applecmr91 * applecmr92).sum().round(2)


macbmr9 = ndf9.loc[(ndf9['Product'] == 'Macbook Pro Laptop') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
maccmr91 = pd.to_numeric(macbmr9['Quantity Ordered'], errors='coerce')
maccmr92 = pd.to_numeric(macbmr9['Price Each'], errors='coerce')
macbmr91 = (maccmr91 * maccmr92).sum().round(2)


flatsmr9 = ndf9.loc[(ndf9['Product'] == 'Flatscreen TV') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
flatscmr91 = pd.to_numeric(flatsmr9['Quantity Ordered'], errors='coerce')
flatscmr92 = pd.to_numeric(flatsmr9['Price Each'], errors='coerce')
flatsmr91 = (flatscmr91 * flatscmr92).sum().round(2)


varemr9 = ndf9.loc[(ndf9['Product'] == 'Vareebadd Phone') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
varecmr91 = pd.to_numeric(varemr9['Quantity Ordered'], errors='coerce')
varecmr92 = pd.to_numeric(varemr9['Price Each'], errors='coerce')
varemr91 = (varecmr91 * varecmr92).sum().round(2)


aamr9 = ndf9.loc[(ndf9['Product'] == 'AA Batteries (4-pack)') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
aacmr91 = pd.to_numeric(aamr9['Quantity Ordered'], errors='coerce')
aacmr92 = pd.to_numeric(aamr9['Price Each'], errors='coerce')
aamr91 = (aacmr91 * aacmr92).sum().round(2)


googmr9 = ndf9.loc[(ndf9['Product'] == 'Google Phone') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
googcmr91 = pd.to_numeric(googmr9['Quantity Ordered'], errors='coerce')
googcmr92 = pd.to_numeric(googmr9['Price Each'], errors='coerce')
googmr91 = (googcmr91 * googcmr92).sum().round(2)


monmr9 = ndf9.loc[(ndf9['Product'] == '20in Monitor') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
moncmr91 = pd.to_numeric(monmr9['Quantity Ordered'], errors='coerce')
moncmr92 = pd.to_numeric(monmr9['Price Each'], errors='coerce')
monmr91 = (moncmr91 * moncmr92).sum().round(2)


ultramr9 = ndf9.loc[(ndf9['Product'] == '34in Ultrawide Monitor') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
ultracmr91 = pd.to_numeric(ultramr9['Quantity Ordered'], errors='coerce')
ultracmr92 = pd.to_numeric(ultramr9['Price Each'], errors='coerce')
ultramr91 = (ultracmr91 * ultracmr92).sum().round(2)


thinkmr9l = ndf9.loc[(ndf9['Product'] == 'ThinkPad Laptop') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
thinkcmr91 = pd.to_numeric(thinkmr9l['Quantity Ordered'], errors='coerce')
thinkcmr92 = pd.to_numeric(thinkmr9l['Price Each'], errors='coerce')
thinklmr91 = (thinkcmr91 * thinkcmr92).sum().round(2)


lgmr9 = ndf9.loc[(ndf9['Product'] == 'LG Dryer') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
lgmrc91 = pd.to_numeric(lgmr9['Quantity Ordered'], errors='coerce')
lgmrc92 = pd.to_numeric(lgmr9['Price Each'], errors='coerce')
lgmr91 = (lgmrc91 * lgmrc92).sum().round(2)


lmmr9 = ndf9.loc[(ndf9['Product'] == 'LG Washing Machine') ^ (ndf9['Quantity Ordered'] == 1) ^ (ndf9['Price Each'] == 1)]
lmmrc91 = pd.to_numeric(lmmr9['Quantity Ordered'], errors='coerce')
lmmrc92 = pd.to_numeric(lmmr9['Price Each'], errors='coerce')
lmmr91 = (lmmrc91 * lmmrc92).sum().round(2)

# month 9 total:
m9tot=ippmr91+lggcabmr91+whphmr91+fhdmonmr91+aaamr91+gammonmr91+usbcccmr91+bosesmr91+applemr91+macbmr91+flatsmr91+varemr91+aamr91+googmr91+monmr91+ultramr91+thinklmr91+lgmr91+lmmr91
m9tot
# Out:
# 2098816.7

# %%
# new monthly rev calculations, month 10
ipmr10 = ndf10.loc[(ndf10['Product'] == 'iPhone') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] ==1)]
ipmrr101 = pd.to_numeric(ipmr10['Quantity Ordered'], errors='coerce')
ipmrr102 = pd.to_numeric(ipmr10['Price Each'], errors='coerce')
ippmr101 = (ipmrr101 * ipmrr102).sum().round(2)

lggcabmr10 = ndf10.loc[(ndf10['Product'] == 'Lightning Charging Cable') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
lgcabmr101 = pd.to_numeric(lggcabmr10['Quantity Ordered'], errors='coerce')
lgcabmr102 = pd.to_numeric(lggcabmr10['Price Each'], errors='coerce')
lggcabmr101 = (lgcabmr101 * lgcabmr102).sum().round(2)


whmr10 = ndf10.loc[(ndf10['Product'] == 'Wired Headphones') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
whmr101 = pd.to_numeric(whmr10['Quantity Ordered'], errors='coerce')
whmr102 = pd.to_numeric(whmr10['Price Each'], errors='coerce')
whphmr101 = (whmr101 * whmr102).sum().round(2)


fhmr10 = ndf10.loc[(ndf10['Product'] == '27in FHD Monitor') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
fhmr101 = pd.to_numeric(fhmr10['Quantity Ordered'], errors='coerce')
fhmr102 = pd.to_numeric(fhmr10['Price Each'], errors='coerce')
fhdmonmr101 = (fhmr101 * fhmr102).sum().round(2)


aaamr10 = ndf10.loc[(ndf10['Product'] == 'AAA Batteries (4-pack)') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
aaabmr101 = pd.to_numeric(aaamr10['Quantity Ordered'], errors='coerce')
aaabmr102 = pd.to_numeric(aaamr10['Price Each'], errors='coerce')
aaamr101 = (aaabmr101 * aaabmr102).sum().round(2)


gmmr10 = ndf10.loc[(ndf10['Product'] == '27in 4K Gaming Monitor') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
gmmr101 = pd.to_numeric(gmmr10['Quantity Ordered'], errors='coerce')
gmmr102 = pd.to_numeric(gmmr10['Price Each'], errors='coerce')
gammonmr101 = (gmmr101 * gmmr102).sum().round(2)


usmr10 = ndf10.loc[(ndf10['Product'] == 'USB-C Charging Cable') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
usmr101 = pd.to_numeric(usmr10['Quantity Ordered'], errors='coerce')
usmr102 = pd.to_numeric(usmr10['Price Each'], errors='coerce')
usbcccmr101 = (usmr101 * usmr102).sum().round(2)


bosesmr10 = ndf10.loc[(ndf10['Product'] == 'Bose SoundSport Headphones') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] ==1)]
bosecmr101 = pd.to_numeric(bosesmr10['Quantity Ordered'], errors='coerce')
bosecmr102 = pd.to_numeric(bosesmr10['Price Each'], errors='coerce')
bosesmr101 = (bosecmr101 * bosecmr102).sum().round(2)


applemr10 =  ndf10.loc[(ndf10['Product'] == 'Apple Airpods Headphones') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
applecmr101 = pd.to_numeric(applemr10['Quantity Ordered'], errors='coerce')
applecmr102 = pd.to_numeric(applemr10['Price Each'], errors='coerce')
applemr101 = (applecmr101 * applecmr102).sum().round(2)


macbmr10 = ndf10.loc[(ndf10['Product'] == 'Macbook Pro Laptop') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
maccmr101 = pd.to_numeric(macbmr10['Quantity Ordered'], errors='coerce')
maccmr102 = pd.to_numeric(macbmr10['Price Each'], errors='coerce')
macbmr101 = (maccmr101 * maccmr102).sum().round(2)


flatsmr10 = ndf10.loc[(ndf10['Product'] == 'Flatscreen TV') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
flatscmr101 = pd.to_numeric(flatsmr10['Quantity Ordered'], errors='coerce')
flatscmr102 = pd.to_numeric(flatsmr10['Price Each'], errors='coerce')
flatsmr101 = (flatscmr101 * flatscmr102).sum().round(2)


varemr10 = ndf10.loc[(ndf10['Product'] == 'Vareebadd Phone') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
varecmr101 = pd.to_numeric(varemr10['Quantity Ordered'], errors='coerce')
varecmr102 = pd.to_numeric(varemr10['Price Each'], errors='coerce')
varemr101 = (varecmr101 * varecmr102).sum().round(2)


aamr10 = ndf10.loc[(ndf10['Product'] == 'AA Batteries (4-pack)') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
aacmr101 = pd.to_numeric(aamr10['Quantity Ordered'], errors='coerce')
aacmr102 = pd.to_numeric(aamr10['Price Each'], errors='coerce')
aamr101 = (aacmr101 * aacmr102).sum().round(2)


googmr10 = ndf10.loc[(ndf10['Product'] == 'Google Phone') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
googcmr101 = pd.to_numeric(googmr10['Quantity Ordered'], errors='coerce')
googcmr102 = pd.to_numeric(googmr10['Price Each'], errors='coerce')
googmr101 = (googcmr101 * googcmr102).sum().round(2)


monmr10 = ndf10.loc[(ndf10['Product'] == '20in Monitor') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
moncmr101 = pd.to_numeric(monmr10['Quantity Ordered'], errors='coerce')
moncmr102 = pd.to_numeric(monmr10['Price Each'], errors='coerce')
monmr101 = (moncmr101 * moncmr102).sum().round(2)


ultramr10 = ndf10.loc[(ndf10['Product'] == '34in Ultrawide Monitor') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
ultracmr101 = pd.to_numeric(ultramr10['Quantity Ordered'], errors='coerce')
ultracmr102 = pd.to_numeric(ultramr10['Price Each'], errors='coerce')
ultramr101 = (ultracmr101 * ultracmr102).sum().round(2)


thinkmr10l = ndf10.loc[(ndf10['Product'] == 'ThinkPad Laptop') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
thinkcmr101 = pd.to_numeric(thinkmr10l['Quantity Ordered'], errors='coerce')
thinkcmr102 = pd.to_numeric(thinkmr10l['Price Each'], errors='coerce')
thinklmr101 = (thinkcmr101 * thinkcmr102).sum().round(2)


lgmr10 = ndf10.loc[(ndf10['Product'] == 'LG Dryer') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
lgmrc101 = pd.to_numeric(lgmr10['Quantity Ordered'], errors='coerce')
lgmrc102 = pd.to_numeric(lgmr10['Price Each'], errors='coerce')
lgmr101 = (lgmrc101 * lgmrc102).sum().round(2)


lmmr10 = ndf10.loc[(ndf10['Product'] == 'LG Washing Machine') ^ (ndf10['Quantity Ordered'] == 1) ^ (ndf10['Price Each'] == 1)]
lmmrc101 = pd.to_numeric(lmmr10['Quantity Ordered'], errors='coerce')
lmmrc102 = pd.to_numeric(lmmr10['Price Each'], errors='coerce')
lmmr101 = (lmmrc101 * lmmrc102).sum().round(2)

# month 10 total:
m10tot=ippmr101+lggcabmr101+whphmr101+fhdmonmr101+aaamr101+gammonmr101+usbcccmr101+bosesmr101+applemr101+macbmr101+flatsmr101+varemr101+aamr101+googmr101+monmr101+ultramr101+thinklmr101+lgmr101+lmmr101
m10tot
# Out:
# 3736884.05

# %%
# new monthly rev calculations, month 11
ipmr11 = ndf11.loc[(ndf11['Product'] == 'iPhone') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] ==1)]
ipmrr111 = pd.to_numeric(ipmr11['Quantity Ordered'], errors='coerce')
ipmrr112 = pd.to_numeric(ipmr11['Price Each'], errors='coerce')
ippmr111 = (ipmrr111 * ipmrr112).sum().round(2)

lgcabmr11 = ndf11.loc[(ndf11['Product'] == 'Lightning Charging Cable') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
lgcabmr111 = pd.to_numeric(lgcabmr11['Quantity Ordered'], errors='coerce')
lgcabmr112 = pd.to_numeric(lgcabmr11['Price Each'], errors='coerce')
lggcabmr111 = (lgcabmr111 * lgcabmr112).sum().round(2)


whmr11 = ndf11.loc[(ndf11['Product'] == 'Wired Headphones') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
whmr111 = pd.to_numeric(whmr11['Quantity Ordered'], errors='coerce')
whmr112 = pd.to_numeric(whmr11['Price Each'], errors='coerce')
whphmr111 = (whmr111 * whmr112).sum().round(2)


fhmr11 = ndf11.loc[(ndf11['Product'] == '27in FHD Monitor') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
fhmr111 = pd.to_numeric(fhmr11['Quantity Ordered'], errors='coerce')
fhmr112 = pd.to_numeric(fhmr11['Price Each'], errors='coerce')
fhdmonmr111 = (fhmr111 * fhmr112).sum().round(2)


aaamr11 = ndf11.loc[(ndf11['Product'] == 'AAA Batteries (4-pack)') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
aaabmr111 = pd.to_numeric(aaamr11['Quantity Ordered'], errors='coerce')
aaabmr112 = pd.to_numeric(aaamr11['Price Each'], errors='coerce')
aaamr111 = (aaabmr111 * aaabmr112).sum().round(2)


gmmr11 = ndf11.loc[(ndf11['Product'] == '27in 4K Gaming Monitor') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
gmmr111 = pd.to_numeric(gmmr11['Quantity Ordered'], errors='coerce')
gmmr112 = pd.to_numeric(gmmr11['Price Each'], errors='coerce')
gammonmr111 = (gmmr111 * gmmr112).sum().round(2)


usmr11 = ndf11.loc[(ndf11['Product'] == 'USB-C Charging Cable') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
usmr111 = pd.to_numeric(usmr11['Quantity Ordered'], errors='coerce')
usmr112 = pd.to_numeric(usmr11['Price Each'], errors='coerce')
usbcccmr111 = (usmr111 * usmr112).sum().round(2)


bosesmr11 = ndf11.loc[(ndf11['Product'] == 'Bose SoundSport Headphones') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] ==1)]
bosecmr111 = pd.to_numeric(bosesmr11['Quantity Ordered'], errors='coerce')
bosecmr112 = pd.to_numeric(bosesmr11['Price Each'], errors='coerce')
bosesmr111 = (bosecmr111 * bosecmr112).sum().round(2)


applemr11 =  ndf11.loc[(ndf11['Product'] == 'Apple Airpods Headphones') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
applecmr111 = pd.to_numeric(applemr11['Quantity Ordered'], errors='coerce')
applecmr112 = pd.to_numeric(applemr11['Price Each'], errors='coerce')
applemr111 = (applecmr111 * applecmr112).sum().round(2)


macbmr11 = ndf11.loc[(ndf11['Product'] == 'Macbook Pro Laptop') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
maccmr111 = pd.to_numeric(macbmr11['Quantity Ordered'], errors='coerce')
maccmr112 = pd.to_numeric(macbmr11['Price Each'], errors='coerce')
macbmr111 = (maccmr111 * maccmr112).sum().round(2)


flatsmr11 = ndf11.loc[(ndf11['Product'] == 'Flatscreen TV') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
flatscmr111 = pd.to_numeric(flatsmr11['Quantity Ordered'], errors='coerce')
flatscmr112 = pd.to_numeric(flatsmr11['Price Each'], errors='coerce')
flatsmr111 = (flatscmr111 * flatscmr112).sum().round(2)


varemr11 = ndf11.loc[(ndf11['Product'] == 'Vareebadd Phone') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
varecmr111 = pd.to_numeric(varemr11['Quantity Ordered'], errors='coerce')
varecmr112 = pd.to_numeric(varemr11['Price Each'], errors='coerce')
varemr111 = (varecmr111 * varecmr112).sum().round(2)


aamr11 = ndf11.loc[(ndf11['Product'] == 'AA Batteries (4-pack)') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
aacmr111 = pd.to_numeric(aamr11['Quantity Ordered'], errors='coerce')
aacmr112 = pd.to_numeric(aamr11['Price Each'], errors='coerce')
aamr111 = (aacmr111 * aacmr112).sum().round(2)


googmr11 = ndf11.loc[(ndf11['Product'] == 'Google Phone') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
googcmr111 = pd.to_numeric(googmr11['Quantity Ordered'], errors='coerce')
googcmr112 = pd.to_numeric(googmr11['Price Each'], errors='coerce')
googmr111 = (googcmr111 * googcmr112).sum().round(2)


monmr11 = ndf11.loc[(ndf11['Product'] == '20in Monitor') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
moncmr111 = pd.to_numeric(monmr11['Quantity Ordered'], errors='coerce')
moncmr112 = pd.to_numeric(monmr11['Price Each'], errors='coerce')
monmr111 = (moncmr111 * moncmr112).sum().round(2)


ultramr11 = ndf11.loc[(ndf11['Product'] == '34in Ultrawide Monitor') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
ultracmr111 = pd.to_numeric(ultramr11['Quantity Ordered'], errors='coerce')
ultracmr112 = pd.to_numeric(ultramr11['Price Each'], errors='coerce')
ultramr111 = (ultracmr111 * ultracmr112).sum().round(2)


thinkmr11l = ndf11.loc[(ndf11['Product'] == 'ThinkPad Laptop') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
thinkcmr111 = pd.to_numeric(thinkmr11l['Quantity Ordered'], errors='coerce')
thinkcmr112 = pd.to_numeric(thinkmr11l['Price Each'], errors='coerce')
thinklmr111 = (thinkcmr111 * thinkcmr112).sum().round(2)


lgmr11 = ndf11.loc[(ndf11['Product'] == 'LG Dryer') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
lgmrc111 = pd.to_numeric(lgmr11['Quantity Ordered'], errors='coerce')
lgmrc112 = pd.to_numeric(lgmr11['Price Each'], errors='coerce')
lgmr111 = (lgmrc111 * lgmrc112).sum().round(2)


lmmr11 = ndf11.loc[(ndf11['Product'] == 'LG Washing Machine') ^ (ndf11['Quantity Ordered'] == 1) ^ (ndf11['Price Each'] == 1)]
lmmrc111 = pd.to_numeric(lmmr11['Quantity Ordered'], errors='coerce')
lmmrc112 = pd.to_numeric(lmmr11['Price Each'], errors='coerce')
lmmr111 = (lmmrc111 * lmmrc112).sum().round(2)


# month 11 total:
m11tot=ippmr111+lggcabmr111+whphmr111+fhdmonmr111+aaamr111+gammonmr111+usbcccmr111+bosesmr111+applemr111+macbmr111+flatsmr111+varemr111+aamr111+googmr111+monmr111+ultramr111+thinklmr111+lgmr111+lmmr111
m11tot
# Out:
# 3198909.2300000004

# %%
# new monthly rev calculations, month 12
ipmr12 = ndf12.loc[(ndf12['Product'] == 'iPhone') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] ==1)]
ipmrr121 = pd.to_numeric(ipmr12['Quantity Ordered'], errors='coerce')
ipmrr122 = pd.to_numeric(ipmr12['Price Each'], errors='coerce')
ippmr121 = (ipmrr121 * ipmrr122).sum().round(2)

lgcabmr12 = ndf12.loc[(ndf12['Product'] == 'Lightning Charging Cable') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
lgcabmr121 = pd.to_numeric(lgcabmr12['Quantity Ordered'], errors='coerce')
lgcabmr122 = pd.to_numeric(lgcabmr12['Price Each'], errors='coerce')
lggcabmr121 = (lgcabmr121 * lgcabmr122).sum().round(2)


whmr12 = ndf12.loc[(ndf12['Product'] == 'Wired Headphones') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
whmr121 = pd.to_numeric(whmr12['Quantity Ordered'], errors='coerce')
whmr122 = pd.to_numeric(whmr12['Price Each'], errors='coerce')
whphmr121 = (whmr121 * whmr122).sum().round(2)


fhmr12 = ndf12.loc[(ndf12['Product'] == '27in FHD Monitor') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
fhmr121 = pd.to_numeric(fhmr12['Quantity Ordered'], errors='coerce')
fhmr122 = pd.to_numeric(fhmr12['Price Each'], errors='coerce')
fhdmonmr121 = (fhmr121 * fhmr122).sum().round(2)


aaamr12 = ndf12.loc[(ndf12['Product'] == 'AAA Batteries (4-pack)') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
aaabmr121 = pd.to_numeric(aaamr12['Quantity Ordered'], errors='coerce')
aaabmr122 = pd.to_numeric(aaamr12['Price Each'], errors='coerce')
aaamr121 = (aaabmr121 * aaabmr122).sum().round(2)


gmmr12 = ndf12.loc[(ndf12['Product'] == '27in 4K Gaming Monitor') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
gmmr121 = pd.to_numeric(gmmr12['Quantity Ordered'], errors='coerce')
gmmr122 = pd.to_numeric(gmmr12['Price Each'], errors='coerce')
gammonmr121 = (gmmr111 * gmmr122).sum().round(2)


usmr12 = ndf12.loc[(ndf12['Product'] == 'USB-C Charging Cable') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
usmr121 = pd.to_numeric(usmr12['Quantity Ordered'], errors='coerce')
usmr122 = pd.to_numeric(usmr12['Price Each'], errors='coerce')
usbcccmr121 = (usmr121 * usmr122).sum().round(2)


bosesmr12 = ndf12.loc[(ndf12['Product'] == 'Bose SoundSport Headphones') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] ==1)]
bosecmr121 = pd.to_numeric(bosesmr12['Quantity Ordered'], errors='coerce')
bosecmr122 = pd.to_numeric(bosesmr12['Price Each'], errors='coerce')
bosesmr121 = (bosecmr121 * bosecmr122).sum().round(2)


applemr12 =  ndf12.loc[(ndf12['Product'] == 'Apple Airpods Headphones') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
applecmr121 = pd.to_numeric(applemr12['Quantity Ordered'], errors='coerce')
applecmr122 = pd.to_numeric(applemr12['Price Each'], errors='coerce')
applemr121 = (applecmr121 * applecmr122).sum().round(2)


macbmr12 = ndf12.loc[(ndf12['Product'] == 'Macbook Pro Laptop') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
maccmr121 = pd.to_numeric(macbmr12['Quantity Ordered'], errors='coerce')
maccmr122 = pd.to_numeric(macbmr12['Price Each'], errors='coerce')
macbmr121 = (maccmr121 * maccmr122).sum().round(2)


flatsmr12 = ndf12.loc[(ndf12['Product'] == 'Flatscreen TV') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
flatscmr121 = pd.to_numeric(flatsmr12['Quantity Ordered'], errors='coerce')
flatscmr122 = pd.to_numeric(flatsmr12['Price Each'], errors='coerce')
flatsmr121 = (flatscmr121 * flatscmr122).sum().round(2)


varemr12 = ndf12.loc[(ndf12['Product'] == 'Vareebadd Phone') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
varecmr121 = pd.to_numeric(varemr12['Quantity Ordered'], errors='coerce')
varecmr122 = pd.to_numeric(varemr12['Price Each'], errors='coerce')
varemr121 = (varecmr111 * varecmr122).sum().round(2)


aamr12 = ndf12.loc[(ndf12['Product'] == 'AA Batteries (4-pack)') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
aacmr121 = pd.to_numeric(aamr12['Quantity Ordered'], errors='coerce')
aacmr122 = pd.to_numeric(aamr12['Price Each'], errors='coerce')
aamr121 = (aacmr121 * aacmr122).sum().round(2)


googmr12 = ndf12.loc[(ndf12['Product'] == 'Google Phone') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
googcmr121 = pd.to_numeric(googmr12['Quantity Ordered'], errors='coerce')
googcmr122 = pd.to_numeric(googmr12['Price Each'], errors='coerce')
googmr121 = (googcmr121 * googcmr122).sum().round(2)


monmr12 = ndf12.loc[(ndf12['Product'] == '20in Monitor') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
moncmr121 = pd.to_numeric(monmr12['Quantity Ordered'], errors='coerce')
moncmr122 = pd.to_numeric(monmr12['Price Each'], errors='coerce')
monmr121 = (moncmr121 * moncmr122).sum().round(2)


ultramr12 = ndf12.loc[(ndf12['Product'] == '34in Ultrawide Monitor') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
ultracmr121 = pd.to_numeric(ultramr12['Quantity Ordered'], errors='coerce')
ultracmr122 = pd.to_numeric(ultramr12['Price Each'], errors='coerce')
ultramr121 = (ultracmr121 * ultracmr122).sum().round(2)


thinkmr12l = ndf12.loc[(ndf12['Product'] == 'ThinkPad Laptop') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
thinkcmr121 = pd.to_numeric(thinkmr12l['Quantity Ordered'], errors='coerce')
thinkcmr122 = pd.to_numeric(thinkmr12l['Price Each'], errors='coerce')
thinklmr121 = (thinkcmr121 * thinkcmr121).sum().round(2)


lgmr12 = ndf12.loc[(ndf12['Product'] == 'LG Dryer') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
lgmrc121 = pd.to_numeric(lgmr12['Quantity Ordered'], errors='coerce')
lgmrc122 = pd.to_numeric(lgmr12['Price Each'], errors='coerce')
lgmr121 = (lgmrc121 * lgmrc122).sum().round(2)


lmmr12 = ndf12.loc[(ndf12['Product'] == 'LG Washing Machine') ^ (ndf12['Quantity Ordered'] == 1) ^ (ndf12['Price Each'] == 1)]
lmmrc121 = pd.to_numeric(lmmr12['Quantity Ordered'], errors='coerce')
lmmrc122 = pd.to_numeric(lmmr12['Price Each'], errors='coerce')
lmmr121 = (lmmrc121 * lmmrc122).sum().round(2)

#  month 12 total:
m12tot=ippmr121+lggcabmr121+whphmr121+fhdmonmr121+aaamr121+gammonmr121+usbcccmr121+bosesmr121+applemr121+macbmr121+flatsmr121+varemr121+aamr121+googmr121+monmr121+ultramr121+thinklmr121+lgmr121+lmmr121
m12tot
# Out:
# 3637261.9400000004

# %%
# Conversions for total products sold per month to floats
m1 = pd.to_numeric(ndf1['Quantity Ordered'], errors='coerce')
m2 = pd.to_numeric(ndf2['Quantity Ordered'], errors='coerce')
m3 = pd.to_numeric(ndf3['Quantity Ordered'], errors='coerce')
m4 = pd.to_numeric(ndf4['Quantity Ordered'], errors='coerce')
m5 = pd.to_numeric(ndf5['Quantity Ordered'], errors='coerce')
m6 = pd.to_numeric(ndf6['Quantity Ordered'], errors='coerce')
m7 = pd.to_numeric(ndf7['Quantity Ordered'], errors='coerce')
m8 = pd.to_numeric(ndf8['Quantity Ordered'], errors='coerce')
m9 = pd.to_numeric(ndf9['Quantity Ordered'], errors='coerce')
m10 = pd.to_numeric(ndf10['Quantity Ordered'], errors='coerce')
m11 = pd.to_numeric(ndf11['Quantity Ordered'], errors='coerce')
m12 = pd.to_numeric(ndf12['Quantity Ordered'], errors='coerce')



mydf = pd.DataFrame({
    'Number Of Products Sold Per Month': [m1.sum(), m2.sum(),
                                       m3.sum(), m4.sum(), m5.sum(),
                                       m6.sum(), m7.sum(),
                                       m8.sum(), m9.sum(), m10.sum(),
                                       m11.sum(), m12.sum()]

    
},index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
columns = ['Number Of Products Sold Per Month'] 
mydf
# Out:
#      Number Of Products Sold Per Month
# Jan                            10868.0
# Feb                            13461.0
# Mar                            17006.0
# Apr                            20568.0
# May                            18657.0
# Jun                            15255.0
# Jul                            16069.0
# Aug                            13442.0
# Sep                            13119.0
# Oct                            22705.0
# Nov                            19808.0
# Dec                            28121.0

# %%
mydf.plot()
# Out:
# <AxesSubplot:>

# %%
# Calculating Monthly Revenue and tabulating results
mydf2 = pd.DataFrame({
    'Monthly Revenue': [m1tot, m2tot, m3tot, m4tot, m5tot, m6tot, m7tot, m8tot, m9tot, m10tot, m11tot, m12tot]

    
},index = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
columns = ['Monthly Revenue'] 
mydf2
# Out:
#      Monthly Revenue
# Jan       1815335.12
# Feb       2203481.24
# Mar       2809063.30
# Apr       3396059.11
# May       3144584.80
# Jun       2578293.30
# Jul       2646899.69
# Aug       2244412.31
# Sep       2098816.70
# Oct       3736884.05
# Nov       3198909.23
# Dec       3637261.94

# %%
mydf2.plot()
# Out:
# <AxesSubplot:>

# %%
# Income Received from all products (according to quantity sold)
ip1 = df_keys.loc[(df_keys['Product'] == 'iPhone') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
ipp1 = pd.to_numeric(ip1['Quantity Ordered'], errors='coerce')
ipp2 = pd.to_numeric(ip1['Price Each'], errors='coerce')
ippr1 = (ipp1 * ipp2).sum().round(2)

# Income made from iPhone sales
lgcab = df_keys.loc[(df_keys['Product'] == 'Lightning Charging Cable') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
lgcab1 = pd.to_numeric(lgcab['Quantity Ordered'], errors='coerce')
lgcab2 = pd.to_numeric(lgcab['Price Each'], errors='coerce')
lggcab1 = (lgcab1 * lgcab2).sum().round(2)

# Income made from Lightning Charging Cable sales
wh = df_keys.loc[(df_keys['Product'] == 'Wired Headphones') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
wh1 = pd.to_numeric(wh['Quantity Ordered'], errors='coerce')
wh2 = pd.to_numeric(wh['Price Each'], errors='coerce')
whph1 = (wh1 * wh2).sum().round(2)

# Income made from Wired Headphones sales
fh = df_keys.loc[(df_keys['Product'] == '27in FHD Monitor') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
fh1 = pd.to_numeric(fh['Quantity Ordered'], errors='coerce')
fh2 = pd.to_numeric(fh['Price Each'], errors='coerce')
fhdmon1 = (fh1 * fh2).sum().round(2)

# Income made from 27in FHD Monitor sales
aaa = df_keys.loc[(df_keys['Product'] == 'AAA Batteries (4-pack)') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
aaab1 = pd.to_numeric(aaa['Quantity Ordered'], errors='coerce')
aaab2 = pd.to_numeric(aaa['Price Each'], errors='coerce')
aaa1 = (aaab1 * aaab2).sum().round(2)

# Income made from AAA Batteries (4-pack) sales
gm = df_keys.loc[(df_keys['Product'] == '27in 4K Gaming Monitor') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
gm1 = pd.to_numeric(gm['Quantity Ordered'], errors='coerce')
gm2 = pd.to_numeric(gm['Price Each'], errors='coerce')
gammon1 = (gm1 * gm2).sum().round(2)

# Income made from 27in 4K Gaming Monitor sales
us = df_keys.loc[(df_keys['Product'] == 'USB-C Charging Cable') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
us1 = pd.to_numeric(us['Quantity Ordered'], errors='coerce')
us2 = pd.to_numeric(us['Price Each'], errors='coerce')
usbccc1 = (us1 * us2).sum().round(2)

# Income made from USB-C Charging Cable sales

boses = df_keys.loc[(df_keys['Product'] == 'Bose SoundSport Headphones') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
bosec1 = pd.to_numeric(boses['Quantity Ordered'], errors='coerce')
bosec2 = pd.to_numeric(boses['Price Each'], errors='coerce')
boses1 = (bosec1 * bosec2).sum().round(2)
# Income from Bose SoundSport Headphones sales

apple =  df_keys.loc[(df_keys['Product'] == 'Apple Airpods Headphones') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
applec1 = pd.to_numeric(apple['Quantity Ordered'], errors='coerce')
applec2 = pd.to_numeric(apple['Price Each'], errors='coerce')
apple1 = (applec1 * applec2).sum().round(2)
#Income from Apple Airpods Headphones sales

macb = df_keys.loc[(df_keys['Product'] == 'Macbook Pro Laptop') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
macc1 = pd.to_numeric(macb['Quantity Ordered'], errors='coerce')
macc2 = pd.to_numeric(macb['Price Each'], errors='coerce')
macb1 = (macc1 * macc2).sum().round(2)
# Income from Macbook Pro Laptop sales

flats = df_keys.loc[(df_keys['Product'] == 'Flatscreen TV') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
flatsc1 = pd.to_numeric(flats['Quantity Ordered'], errors='coerce')
flatsc2 = pd.to_numeric(flats['Price Each'], errors='coerce')
flats1 = (flatsc1 * flatsc2).sum().round(2)
# Income from Flatscreen TV sales

vare = df_keys.loc[(df_keys['Product'] == 'Vareebadd Phone') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
varec1 = pd.to_numeric(vare['Quantity Ordered'], errors='coerce')
varec2 = pd.to_numeric(vare['Price Each'], errors='coerce')
vare1 = (varec1 * varec2).sum().round(2)
# Income from Vareebadd Phone sales 

aa = df_keys.loc[(df_keys['Product'] == 'AA Batteries (4-pack)') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
aac1 = pd.to_numeric(aa['Quantity Ordered'], errors='coerce')
aac2 = pd.to_numeric(aa['Price Each'], errors='coerce')
aa1 = (aac1 * aac2).sum().round(2)
# Income from AA Batteries 4-pack sales

goog = df_keys.loc[(df_keys['Product'] == 'Google Phone') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
googc1 = pd.to_numeric(goog['Quantity Ordered'], errors='coerce')
googc2 = pd.to_numeric(goog['Price Each'], errors='coerce')
goog1 = (googc1 * googc2).sum().round(2)
# Income from Google Phone sales

mon = df_keys.loc[(df_keys['Product'] == '20in Monitor') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
monc1 = pd.to_numeric(mon['Quantity Ordered'], errors='coerce')
monc2 = pd.to_numeric(mon['Price Each'], errors='coerce')
mon1 = (monc1 * monc2).sum().round(2)
# Income fromm 20in Monitor sales

ultra = df_keys.loc[(df_keys['Product'] == '34in Ultrawide Monitor') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
ultrac1 = pd.to_numeric(ultra['Quantity Ordered'], errors='coerce')
ultrac2 = pd.to_numeric(ultra['Price Each'], errors='coerce')
ultra1 = (ultrac1 * ultrac2).sum().round(2)
# Income from 34in Ultrawide Monitor sales

thinkl = df_keys.loc[(df_keys['Product'] == 'ThinkPad Laptop') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
thinkc1 = pd.to_numeric(thinkl['Quantity Ordered'], errors='coerce')
thinkc2 = pd.to_numeric(thinkl['Price Each'], errors='coerce')
thinkl1 = (thinkc1 * thinkc2).sum().round(2)
# Income from ThinkPad Laptop sales

lg = df_keys.loc[(df_keys['Product'] == 'LG Dryer') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
lgc1 = pd.to_numeric(lg['Quantity Ordered'], errors='coerce')
lgc2 = pd.to_numeric(lg['Price Each'], errors='coerce')
lg1 = (lgc1 * lgc2).sum().round(2)
# Income from LG Dryer sales

lm = df_keys.loc[(df_keys['Product'] == 'LG Washing Machine') ^ (df_keys['Quantity Ordered'] == 1) ^ (df_keys['Price Each'] == 1)]
lmc1 = pd.to_numeric(lm['Quantity Ordered'], errors='coerce')
lmc2 = pd.to_numeric(lm['Price Each'], errors='coerce')
lm1 = (lmc1 * lmc2).sum().round(2)
# Income from LG Washing Machine sales

# Total Revenue
tot_rev = ippr1 + lggcab1 + whph1 + fhdmon1 + aaa1 + gammon1 + usbccc1 + boses1 + apple1 + macb1 + flats1 + vare1 + aa1 + goog1 + mon1 + ultra1 + thinkl1 + lg1 + lm1
tot_rev
# Out:
# 34492035.97

# %%
us_tax_rate = 0.1
tax = tot_rev * us_tax_rate
print(f'The US Government collected {tax.round(2)}USD as tax')
# Out:
# The US Government collected 3449203.6USD as tax

# %%
# Net Revenue
Net_Rev = tot_rev - tax
print(f'Net Revenue: {Net_Rev.round(2)}USD')
# Out:
# Net Revenue: 31042832.37USD

# %%
# Number of Products Sold Growth Rate per month
gm2 = ((m2.sum()-m1.sum())/m1.sum()) * 100
gm3 = ((m3.sum()-m2.sum())/m2.sum()) * 100
gm4 = ((m4.sum()-m3.sum())/m3.sum()) * 100
gm5 = ((m5.sum()-m4.sum())/m4.sum()) * 100
gm6 = ((m6.sum()-m5.sum())/m5.sum()) * 100
gm7 = ((m7.sum()-m6.sum())/m6.sum()) * 100
gm8 = ((m8.sum()-m7.sum())/m7.sum()) * 100
gm9 = ((m9.sum()-m8.sum())/m8.sum()) * 100
gm10 = ((m10.sum()-m9.sum())/m9.sum()) * 100
gm11 = ((m11.sum()-m10.sum())/m10.sum()) * 100
gm12 = ((m12.sum()-m11.sum())/m11.sum()) * 100

# Monthly Revenue Growth Rate
gmm2 = ((m2tot-m1tot)/m1tot) * 100
gmm3 = ((m3tot-m2tot)/m2tot) * 100
gmm4 = ((m4tot-m3tot)/m3tot) * 100
gmm5 = ((m5tot-m4tot)/m4tot) * 100
gmm6 = ((m6tot-m5tot)/m5tot) * 100
gmm7 = ((m7tot-m6tot)/m6tot) * 100
gmm8 = ((m8tot-m7tot)/m7tot) * 100
gmm9 = ((m9tot-m8tot)/m8tot) * 100
gmm10 = ((m10tot-m9tot)/m9tot) * 100
gmm11 = ((m11tot-m10tot)/m10tot) * 100
gmm12 = ((m12tot-m11tot)/m11tot) * 100
         
gm12
# Out:
# 41.967891760904685

# %%
prodgrowth = pd.DataFrame({
    'Product Growth Rate per month (%)':[gm2.round(2), gm3.round(2), gm4.round(2), gm5.round(2), gm6.round(2), gm7.round(2), gm8.round(2), gm9.round(2), gm10.round(2), gm11.round(2), gm12.round(2)]
    
})
prodgrowth.index = ['Jan-Feb', 'Feb-Mar', 'Mar-Apr', 'Apr-May', 'May-Jun', 'Jun-Jul', 'Jul-Aug', 'Aug-Sep', 'Sep-Oct', 'Oct-Nov', 'Nov-Dec']

prodgrowth
# Out:
#          Product Growth Rate per month (%)
# Jan-Feb                              23.86
# Feb-Mar                              26.34
# Mar-Apr                              20.95
# Apr-May                              -9.29
# May-Jun                             -18.23
# Jun-Jul                               5.34
# Jul-Aug                             -16.35
# Aug-Sep                              -2.40
# Sep-Oct                              73.07
# Oct-Nov                             -12.76
# Nov-Dec                              41.97

# %%
ax = prodgrowth.plot(kind='bar', title ="Product Growth Per Month",figsize=(7,4),legend=True, fontsize=12)
ax.set_xlabel("Months",fontsize=12)
ax.set_ylabel("Growth Rate(%)",fontsize=12)
plt.show()

# %%
revgrowth = pd.DataFrame({
    'Montly Revenue Growth Rate per month (%)':[gmm2.round(2), gmm3.round(2), gmm4.round(2), gmm5.round(2), gmm6.round(2), gmm7.round(2), gmm8.round(2), gmm9.round(2), gmm10.round(2), gmm11.round(2), gmm12.round(2)]
    
})
revgrowth.index = ['Jan-Feb', 'Feb-Mar', 'Mar-Apr', 'Apr-May', 'May-Jun', 'Jun-Jul', 'Jul-Aug', 'Aug-Sep', 'Sep-Oct', 'Oct-Nov', 'Nov-Dec']

revgrowth
# Out:
#          Montly Revenue Growth Rate per month (%)
# Jan-Feb                                     21.38
# Feb-Mar                                     27.48
# Mar-Apr                                     20.90
# Apr-May                                     -7.40
# May-Jun                                    -18.01
# Jun-Jul                                      2.66
# Jul-Aug                                    -15.21
# Aug-Sep                                     -6.49
# Sep-Oct                                     78.05
# Oct-Nov                                    -14.40
# Nov-Dec                                     13.70

# %%
ax = revgrowth.plot(kind='bar', title ="Monthly Revenue Growth ",figsize=(7,4),legend=True, fontsize=12)
ax.set_xlabel("Months",fontsize=12)
ax.set_ylabel("Growth Rate(%)",fontsize=12)
plt.show()

# %%
avgProdGR = (((gm12/gm2)-1)*100).round(2)
avgMonGR = (((m12tot/m2tot)-1)*100).round(2)
avgProdGR
# Out:
# 75.9

# %%
tot_prods = mydf.sum()
tot_prods
# Out:
# Number Of Products Sold Per Month    209079.0
# dtype: float64

# %%
#piechart conversions

#averages:
pavgProdGR = (avgProdGR/360)*100
pavgMonGR = (avgMonGR/360)*100
pavgProdGR

#totals:
pTot_Rev = (tot_rev/360)*100
pTot_Prods = (tot_prods/360)*100
pTot_Rev
# Out:
# 21.083333333333336

# %%
 pieframe = pd.DataFrame({
     'Annual Data': [pavgProdGR.round(2), pavgMonGR.round(2)]
}, index = ['Average Product Growth Rate', 'Average Revenue Growth Rate'])
columns = ['Annual Data']
pieframe
# Out:
#                              Annual Data
# Average Product Growth Rate        21.08
# Average Revenue Growth Rate        18.08

# %%
plt.figure(figsize=(13,10))
ax1 = plt.subplot(121, aspect='equal')
pieframe.plot(kind='pie', y = 'Annual Data', ax=ax1, autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=pieframe.index, legend = False, fontsize=14)
# Out:
# <AxesSubplot:ylabel='Annual Data'>

# %%
prods = df_keys.drop_duplicates(subset=['Product'])
prods
# Out:
#               Order ID                     Product  Quantity Ordered  \
# January 0       141234                      iPhone                 1
#         1       141235    Lightning Charging Cable                 1
#         2       141236            Wired Headphones                 2
#         3       141237            27in FHD Monitor                 1
#         5       141239      AAA Batteries (4-pack)                 1
#         6       141240      27in 4K Gaming Monitor                 1
#         7       141241        USB-C Charging Cable                 1
#         8       141242  Bose SoundSport Headphones                 1
#         9       141243    Apple Airpods Headphones                 1
#         11      141245          Macbook Pro Laptop                 1
#         14      141248               Flatscreen TV                 1
#         16      141250             Vareebadd Phone                 1
#         19      141253       AA Batteries (4-pack)                 1
# ...

# %%
df_keys
# Out:
#                Order ID                     Product Quantity Ordered  \
# January  0       141234                      iPhone                1
#          1       141235    Lightning Charging Cable                1
#          2       141236            Wired Headphones                2
#          3       141237            27in FHD Monitor                1
#          4       141238            Wired Headphones                1
# ...                 ...                         ...              ...
# December 25112   319666    Lightning Charging Cable                1
#          25113   319667       AA Batteries (4-pack)                2
#          25114   319668             Vareebadd Phone                1
#          25115   319669            Wired Headphones                1
#          25116   319670  Bose SoundSport Headphones                1
#
#                Price Each      Order Date  \
# January  0            700  01/22/19 21:25
#          1          14.95  01/28/19 14:15
# ...

# %%
iphone1 = df_keys.loc[(df_keys['Product'] == 'iPhone') ^ (df_keys['Quantity Ordered'] == 1)]
iph = pd.to_numeric(iphone1['Quantity Ordered'], errors='coerce')
iph1 = iph.sum()
iph1
# Out:
# 6849

# %%
lightning_cab1 = df_keys.loc[(df_keys['Product'] == 'Lightning Charging Cable') ^ (df_keys['Quantity Ordered'] == 1)]
lgtc = pd.to_numeric(lightning_cab1['Quantity Ordered'], errors='coerce')
lgtc1 = lgtc.sum()
lgtc1
# Out:
# 23217

# %%
Wired_Headphones1 = df_keys.loc[(df_keys['Product'] == 'Wired Headphones') ^ (df_keys['Quantity Ordered'] == 1)]
whd = pd.to_numeric(Wired_Headphones1['Quantity Ordered'], errors='coerce')
whd1 = whd.sum()
whd1
# Out:
# 20557

# %%
tsin_FHD_Monitor1 =  df_keys.loc[(df_keys['Product'] == '27in FHD Monitor') ^ (df_keys['Quantity Ordered'] == 1)] 
tsin = pd.to_numeric(tsin_FHD_Monitor1['Quantity Ordered'], errors='coerce')
tsin1 = tsin.sum()
tsin1
# Out:
# 7550

# %%
AAA_Batteries1 = df_keys.loc[(df_keys['Product'] == 'AAA Batteries (4-pack)') ^ (df_keys['Quantity Ordered'] == 1)]
aaabat = pd.to_numeric(AAA_Batteries1['Quantity Ordered'], errors='coerce')
aaabat1 = aaabat.sum()
aaabat1
# Out:
# 31017

# %%
tsin_4K_Gaming_Monitor1 = df_keys.loc[(df_keys['Product'] == '27in 4K Gaming Monitor') ^ (df_keys['Quantity Ordered'] == 1)]
tsin4k = pd.to_numeric(tsin_4K_Gaming_Monitor1['Quantity Ordered'], errors='coerce')
tsin4k1 = tsin4k.sum()
tsin4k1
# Out:
# 6244

# %%
USB_C_Charging_Cable1 = df_keys.loc[(df_keys['Product'] == 'USB-C Charging Cable') ^ (df_keys['Quantity Ordered'] == 1)]
usbc = pd.to_numeric(USB_C_Charging_Cable1['Quantity Ordered'], errors='coerce')
usbc1 = usbc.sum()
usbc1
# Out:
# 23975

# %%
Bose_SoundSport_Headphones1 = df_keys.loc[(df_keys['Product'] == 'Bose SoundSport Headphones') ^ (df_keys['Quantity Ordered'] == 1)]
bose = pd.to_numeric(Bose_SoundSport_Headphones1['Quantity Ordered'], errors='coerce')
bose1 = bose.sum()
bose1
# Out:
# 13457

# %%
Apple_Airpods_Headphones1 = df_keys.loc[(df_keys['Product'] == 'Apple Airpods Headphones') ^ (df_keys['Quantity Ordered'] == 1)]
app = pd.to_numeric(Apple_Airpods_Headphones1['Quantity Ordered'], errors='coerce')
app1 = app.sum()
app1
# Out:
# 15661

# %%
Macbook_Pro_Laptop1 = df_keys.loc[(df_keys['Product'] == 'Macbook Pro Laptop') ^ (df_keys['Quantity Ordered'] == 1)]
mac = pd.to_numeric(Macbook_Pro_Laptop1['Quantity Ordered'], errors='coerce')
mac1 = mac.sum()
mac1
# Out:
# 4728

# %%
Flatscreen_TV1 = df_keys.loc[(df_keys['Product'] == 'Flatscreen TV') ^ (df_keys['Quantity Ordered'] == 1)]
flat = pd.to_numeric(Flatscreen_TV1['Quantity Ordered'], errors='coerce')
flat1 = flat.sum()
flat1
# Out:
# 4819

# %%
Vareebadd_Phone1 = df_keys.loc[(df_keys['Product'] == 'Vareebadd Phone') ^ (df_keys['Quantity Ordered'] == 1)]
var = pd.to_numeric(Vareebadd_Phone1['Quantity Ordered'], errors='coerce')
var1 = var.sum()
var1
# Out:
# 2068

# %%
AA_Batteries_4_pack1 = df_keys.loc[(df_keys['Product'] == 'AA Batteries (4-pack)') ^ (df_keys['Quantity Ordered'] == 1)]
aabat = pd.to_numeric(AA_Batteries_4_pack1['Quantity Ordered'], errors='coerce')
aabat1 = aabat.sum()
aabat1
# Out:
# 27635

# %%
Google_Phone1 = df_keys.loc[(df_keys['Product'] == 'Google Phone') ^ (df_keys['Quantity Ordered'] == 1)]
gog = pd.to_numeric(Google_Phone1['Quantity Ordered'], errors='coerce')
gog1 = gog.sum()
gog1
# Out:
# 5532

# %%
twin_Monitor1 = df_keys.loc[(df_keys['Product'] == '20in Monitor') ^ (df_keys['Quantity Ordered'] == 1)]
twin = pd.to_numeric(twin_Monitor1['Quantity Ordered'], errors='coerce')
twin1 = twin.sum()
twin1
# Out:
# 4129

# %%
tfin_Ultrawide_Monitor1 = df_keys.loc[(df_keys['Product'] == '34in Ultrawide Monitor') ^ (df_keys['Quantity Ordered'] == 1)]
tfin = pd.to_numeric(tfin_Ultrawide_Monitor1['Quantity Ordered'], errors='coerce')
tfin1 = tfin.sum()
tfin1
# Out:
# 6199

# %%
ThinkPad_Laptop1 = df_keys.loc[(df_keys['Product'] == 'ThinkPad Laptop') ^ (df_keys['Quantity Ordered'] == 1)]
think = pd.to_numeric(ThinkPad_Laptop1['Quantity Ordered'], errors='coerce')
think1 = think.sum()
think1
# Out:
# 4130

# %%
LG_Dryer1 = df_keys.loc[(df_keys['Product'] == 'LG Dryer') ^ (df_keys['Quantity Ordered'] == 1)]
lgd = pd.to_numeric(LG_Dryer1['Quantity Ordered'], errors='coerce')
lgd1 = lgd.sum()
lgd1
# Out:
# 646

# %%
LG_Washing_Machine1 = df_keys.loc[(df_keys['Product'] == 'LG Washing Machine') ^ (df_keys['Quantity Ordered'] == 1)]
lgm = pd.to_numeric(LG_Washing_Machine1 ['Quantity Ordered'], errors='coerce')
lgm1 = lgm.sum()
lgm1
# Out:
# 666

# %%
products = pd.DataFrame({
    'Total Number of Products Sold Per Product' : [iph1, lgtc1, whd1, tsin1, aaabat1, tsin4k1, usbc1, bose1, app1, mac1, flat1, var1, aabat1, gog1, twin1, tfin1, think1, lgd1, lgm1]
    }, index =  ['iPhone', 'Lightning Charging Cable', 'Wired Headphones', '27in FHD Monitor', 'AAA Batteries (4-pack)', '27in 4K Gaming Monitor', 'USB-C Charging Cable', 'Bose SoundSport Headphones', 'Apple Airpods Headphones', 'Macbook Pro Laptop', 'Flatscreen TV', 'Vareebadd Phone', 'AA Batteries (4-pack)', 'Google Phone', '20in Monitor', '34in Ultrawide Monitor', 'ThinkPad Laptop', 'LG Dryer', 'LG Washing Machine']	)
products
# Out:
#                             Total Number of Products Sold Per Product
# iPhone                                                           6849
# Lightning Charging Cable                                        23217
# Wired Headphones                                                20557
# 27in FHD Monitor                                                 7550
# AAA Batteries (4-pack)                                          31017
# 27in 4K Gaming Monitor                                           6244
# USB-C Charging Cable                                            23975
# Bose SoundSport Headphones                                      13457
# Apple Airpods Headphones                                        15661
# Macbook Pro Laptop                                               4728
# Flatscreen TV                                                    4819
# Vareebadd Phone                                                  2068
# ...

# %%
ax1 = products.plot(kind='bar', title ='Total Number of Products Sold Per Product',figsize=(7,4),legend=True, fontsize=12)
ax1.set_xlabel("Products",fontsize=12)
ax1.set_ylabel("Product Performance",fontsize=12)
plt.show()
